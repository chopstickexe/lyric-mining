# %%
# dataprocess
from txt2txt_ebc import data_process
df = data_process.to_df("../data/raw/ebc/*.txt")
df.shape
# Out:
# (7341, 3)

# %%
from janome.tokenizer import Tokenizer

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer()
df['wakati_line'] = df['line'].apply(t.tokenize, wakati=True)
df['wakati_line']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=7'>8</a> from janome.tokenizer import Tokenizer
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=8'>9</a> t = Tokenizer()
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=9'>10</a> df['wakati_line'] = df['line'].apply(t.tokenize, wakati=True)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=10'>11</a> df['wakati_line']
#
# NameError: name 'df' is not defined

# %%
# dataprocess
from txt2txt_ebc import data_process
df = data_process.to_df("../data/raw/ebc/*.txt")
df.shape
# Out:
# (6592, 3)

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer()
df['wakati_line'] = df['line'].apply(t.tokenize, wakati=True)
df['wakati_line']
# Out:
# 0                             [ロック, ・, リー, 　, ロック, ・, リー]
# 1       [GO, ！,  , GO, ！,  , Here,  , We,  , Go, ！,  ,...
# 2                               [リーリーリーリー,  , ロック, ・, リー]
# 3                                 [忍術, ムリ, でも, 　, しのび, ！]
# 4                               [リーリーリーリー,  , ロック, ・, リー]
#                               ...
# 6587                        [あなた, と, SING,  , a,  , SONG]
# 6588                           [シンガロン・シンガソン,  , everyday]
# 6589                                              [シンガソン]
# 6590                        [シンガロン・シンガソン,  , for,  , you]
# 6591                                              [シンガソン]
# Name: wakati_line, Length: 6592, dtype: object

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer()
def gen_wakati_txt(txt: str):
    return ' '.join(t.tokenize(txt, wakati=True))
df['wakati_line'] = df['line'].apply(gen_wakati_txt)
df['wakati_line']
# Out:
# 0                             ロック ・ リー 　 ロック ・ リー
# 1       GO ！   GO ！   Here   We   Go ！   ロック ・ リー
# 2                             リーリーリーリー   ロック ・ リー
# 3                                忍術 ムリ でも 　 しのび ！
# 4                             リーリーリーリー   ロック ・ リー
#                           ...
# 6587                        あなた と SING   a   SONG
# 6588                       シンガロン・シンガソン   everyday
# 6589                                        シンガソン
# 6590                      シンガロン・シンガソン   for   you
# 6591                                        シンガソン
# Name: wakati_line, Length: 6592, dtype: object

# %%
# import libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import torch
torch.cuda.is_available()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=15'>16</a> import torch
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=16'>17</a> torch.cuda.is_available()
#
# ModuleNotFoundError: No module named 'torch'

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
df['wakati_line']
# Out:
# 0                             ロック ・ リー 　 ロック ・ リー
# 1       GO ！   GO ！   Here   We   Go ！   ロック ・ リー
# 2                             リーリーリーリー   ロック ・ リー
# 3                                忍術 ムリ でも 　 しのび ！
# 4                             リーリーリーリー   ロック ・ リー
#                           ...
# 6587                        あなた と SING   a   SONG
# 6588                       シンガロン・シンガソン   everyday
# 6589                                        シンガソン
# 6590                      シンガロン・シンガソン   for   you
# 6591                                        シンガソン
# Name: wakati_line, Length: 6592, dtype: object

# %%
# dataprocess
from txt2txt_ebc import data_process
df = data_process.to_df("../data/raw/ebc/*.txt")
df.shape
# Out:
# (6592, 3)

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer()
def gen_wakati_txt(txt: str):
    return ' '.join(t.tokenize(txt, wakati=True))
df['wakati_line'] = df['line'].apply(gen_wakati_txt)
sentences = df['wakati_line'].tolist()
sentences
# Out:
# u3000 メール 打ち ながら ゴロゴロ',
#  'とか 言い つつ も \u3000 明日 は プール アリ \u3000 おおよそ ブラジル',
#  '三 段 重ね アイスクリーム',
#  '扇風機 に 向かっ て スクリーム ( A ” h ” h ” h ” h ” h ” )',
#  '蚊 に 刺さ れ て マジカチン',
#  '頭 突き の ひとつ でも か まし て やり たい',
#  'いつの間にか やぶれ 捨て た   無 遅刻 無 欠席 スローガン',
#  'そん 代わり   大 親友   and   take   care   see   you   放課後 に また',
#  '居眠り ほっぺ の 跡 で   トピック 話題 を さらお う',
#  '照り付ける 日差し   そこ どこ   ここ どこ   こりゃ ほぼ ブラジル',
#  'ほぼ ほぼ ブラジル',
#  'となり は コロンビア',
#  '君 と 僕 の あの 日々 が',
#  'いつも 強く つながっ てる よ',
#  'アイムサーチング   アイムサーチング',
#  'この 先 の 光 に   向かっ て ゆく なら',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '海底 に 潜む   シーラカンス',
#  'ゆっくり と 進化   照らし 出す',
#  '神 が いる として も   い ない として も',
#  '止め たく ない ん だ   僕ら の ストーリー',
#  'アイムサーチング   アイムサーチング',
#  '共に この 想い   あたため て ゆく から',
#  'PLAYBACK   PLAYBACK',
#  '願 わく ば   今 は そば に い て',
#  'PLAYBACK   PLAYBACK',
#  '生まれ変わっ て も   そう 君 の まま で い て',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '再生',
#  '感じとれる   この 先 の 光   見 に 行こ う',
#  'PLAYBACK   PLAYBACK',
#  '願 わく ば   今 は そば に い て',
#  'PLAYBACK   PLAYBACK',
#  '大人 に なっ て も   そう 君 の まま で い て',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  'Uuu',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  '新しい 季節 巡り',
#  '揺るぎない この 想い',
#  '窓 を 開け たら すぐ に',
#  '君 の もと へ 飛び込む よ',
#  '始めよ う 今 この 場所 で',
#  'メラメラ 燃やす 想い',
#  'はち切れ そう な 憂鬱 に',
#  'ハッピー な クラッカー 打ち込ん で',
#  'ねぇ 言葉 じゃ 照れ ちゃう よ',
#  'ごまかし ちゃい そう で',
#  'ねぇ その 手 を 握り',
#  'ステージ に 立っ て 奏でよ う',
#  'あぁ 今 は この リズム に 乗っ て',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら \u3000 ほら   hot   up ！ ！ ！',
#  '数え て み ましょ 羊 さん',
#  'あっち の 夢 は 見る けど',
#  'こっち の 夢 を 叶える の',
#  '今 すぐ 全 速 前進 で',
#  'ねぇ 涙 が 溢れ て',
#  '濡らし た あの 日',
#  'ねぇ 宝物 に なっ て',
#  'この 背中 を 押し て くれる',
#  'あぁ 今 も この リズム に ノ って',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら \u3000 ほら   hot   up ！ ！ ！',
#  '「 私 もう 迷わ ない ！   みんな ー いく よっ ！ 」',
#  'Kick   and   punch   で   We   win ！',
#  'Chop   and   stick   で   Eat   in ！',
#  'Kick   for   kick   は   Win - win ！',
#  'チャンス は どこ ？   Checking ！',
#  '見つけ て   Getting ！',
#  'Big   wave 到来   Swimming ！',
#  'あぁ あの 頃 の 私 たち は きっと',
#  '大切 な 事 を 見失っ て い た ね',
#  'あぁ これから は 誰 に も 負け ない よ',
#  'あなた が くれ た 魔法',
#  '光 の 挿す 方 へ と',
#  'あぁ 今 は この リズム に 乗っ て',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら \u3000 ほら   hot   up ！ ！ ！',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら   ほら   hot   up ！ ！ ！',
#  'さあ さ みんな \u3000 よって らっしゃい \u3000 小麦 ふっ て パン パンパン',
#  '揚げる ん だ \u3000 エビ フライ \u3000 どんと 行っ ちゃっ て',
#  'エビ に 恋せよ 乙女 \u3000 でっかい でっかい の 大好き',
#  '洋食 の \u3000 王様 だ \u3000 ワオ !',
#  '( サクサク 揚げろ 揚げろ 揚げろ )',
#  'ゴクリ 舌なめずり ( ゴクリ )',
#  'みんな テンション 上げ 上げ ( 上げ 上げ )',
#  'パーティー ムード \u3000 なん か いい ぞ !',
#  'それ っ い !',
#  '( え ～ じゃ ない \u3000 ええ じゃ ない \u3000 じゃ ない )',
#  'ロブスター \u3000 オマールエビ \u3000 浮気 し ちゃい そう',
#  'でも 君 に \u3000 一途 だ よ',
#  'サクサク \u3000 プリプリプリ',
#  'パリ パリ \u3000 カリカリカリ',
#  'なんて \u3000 なんて \u3000 美味しい の \u3000 早く 早く \u3000 フライ !',
#  '揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げろ',
#  'エビ フライ 揚げろ \u3000 揚げ \u3000 揚げ \u3000 ジュワジュワジュワ',
#  '揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げろ',
#  'もっと \u3000 テンション',
#  'グイグイグイ \u3000 上げ て',
#  '挙げ \u3000 挙げ \u3000 挙げ \u3000 挙げ \u3000 挙げ \u3000 挙げろ',
#  '拳 挙げろ \u3000 挙げろ \u3000 挙げろ \u3000 ジャンケングー !( あいこ ～!)',
#  '揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げろ',
#  'ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ',
#  '揚げろ !   揚げろ !\u3000( エビ フライ )',
#  'オードブル で 主役 \u3000 フライ 級 の チャンピオン',
#  '学園中 \u3000 人気 沸騰 \u3000 ワオ !',
#  '( テンション 上がる 上がる 上がる )',
#  '熱い 油 の 中 \u3000( あ ち ゅい )',
#  'なんて 君 は たくましい \u3000( たくましい )',
#  '愛し てる \u3000 でも 食べ ちゃう ぞ !',
#  '( え ～ じゃ ない \u3000 ええ じゃ ない \u3000 じゃ ない )',
#  '焼い ちゃ ダメ \u3000 煮 て も ダメ \u3000 もっと 美味しく し て',
#  'こんがり と \u3000 キツネ 色',
#  'サクサク \u3000 プリプリプリ',
#  'パリ パリ \u3000 カリカリカリ',
#  'サクサク \u3000 プリプリプリ \u3000 エビエビエビフライ',
#  '上げ \u3000 上げ \u3000 上げ \u3000 上げ \u3000 上げ \u3000 上げろ',
#  'エビ フライ \u3000 高く \u3000 高く \u3000 高く フライ \u3000 フライ \u3000 フライ',
#  '揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げろ',
#  'もっと \u3000 もっと',
#  'サクサク サク 揚げ て',
#  '挙げ \u3000 挙げ \u3000 挙げ \u3000 挙げ \u3000 挙げ \u3000 挙げろ',
#  '拳 挙げろ \u3000 挙げろ \u3000 挙げろ \u3000 ジャンケンチョキ !( 負け た !)',
#  '上げ \u3000 上げ \u3000 上げ \u3000 上げ \u3000 上げ \u3000 上げろ',
#  'ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ',
#  '揚げろ !   揚げろ !\u3000( エビ フライ )',
#  '大好き ～\u3000 ジュワ ～\u3000 美味しい ～',
#  '揚げ て \u3000 上げ て \u3000 揚げ て \u3000 上げ て',
#  '揚げ て \u3000 上げ て \u3000 揚げ て \u3000 上げ て',
#  '真っ黒 け っけ',
#  '揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げろ',
#  'エビ フライ 揚げろ \u3000 揚げ \u3000 揚げ \u3000 ジュワジュワジュワ',
#  '揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げろ',
#  'もっと \u3000 テンション',
#  'グイグイグイ \u3000 上げ て',
#  '上げ \u3000 上げ \u3000 上げ \u3000 上げ \u3000 上げ \u3000 上げろ',
#  '拳 挙げろ \u3000 挙げろ \u3000 挙げろ \u3000 ジャンケン パー !( 勝っ た ～!)',
#  '揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げ \u3000 揚げろ',
#  'ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ \u3000 ジュワ',
#  '揚げろ !   揚げろ !\u3000( エビ フライ )',
#  'さあ さ みんな \u3000 よって らっしゃい \u3000 小麦 ふっ て パン パンパン',
#  '揚げる ん だ \u3000 エビ フライ \u3000 全部 食べ ちゃっ て !\u3000( ジュワ ～)',
#  'ち ゅっちゅっちゅっちゅっちゅっ \u3000 中学生',
#  'お ばあちゃん \u3000 だって \u3000 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ \u3000 中学生',
#  '高校生 \u3000 だって \u3000 中学生',
#  'いつ でも   ( いつも )   こうして   ( みんな )',
#  'バカ みたい に \u3000 遊ん で たい な',
#  'ち ゅっちゅっちゅっちゅっちゅっ \u3000 中学生',
#  'ヲタ さん \u3000 だって \u3000 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ \u3000 中学生',
#  'スタッフ さん も \u3000 中学生',
#  'ずーっと ね   ( ずーっと )   みんな と   ( ここ で )',
#  '今 の まんま \u3000 笑お う ね !',
#  'ほら \u3000 聞こえ て き まし た \u3000 下校 の ベル です',
#  '本日 \u3000 これ にて \u3000 おしまい',
#  '忘れ物 せ ず に \u3000 帰り ましょ',
#  '少し さみしい な \u3000 下校 の ベル です',
#  'また \u3000 次回 \u3000 お 逢い し ましょ う',
#  '恵比寿 中学 で \u3000 永遠 に \u3000 中学生 !',
#  'ち ゅっちゅっちゅっちゅっちゅっ \u3000 中学生',
#  'いくつ \u3000 だって \u3000 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ \u3000 中学生',
#  '気分 次第 \u3000 中学生',
#  'どんなに   ( いつか )   大きく   ( なっ て も )',
#  'この 気持ち \u3000 忘れ ない',
#  'せ ー の',
#  'キンコンカンコン \u3000 キンコンカンコン \u3000 下校 の ベル です',
#  '初心 \u3000 忘れる べから ず',
#  '全然 \u3000 エラく も ない です が',
#  'おわり の おしらせ \u3000 下校 の ベル です',
#  '次 の \u3000 登校 日 \u3000 いつ でしょ ね',
#  'ホームページ \u3000 チェック し て ね \u3000 永遠 に 中学生 !',
#  '今日 は 来 て くれ て \u3000 ほんとに ありがとう !',
#  'ありがと !',
#  '聞こえ て き まし た \u3000 下校 の ベル です',
#  '本日 \u3000 これ にて \u3000 おしまい',
#  '忘れ物 せ ず に \u3000 帰り ましょ',
#  '少し さみしい な \u3000 下校 の ベル です',
#  'また \u3000 次回 \u3000 お 逢い し ましょ う',
#  '恵比寿 中学 で \u3000 永遠 に \u3000 中学生 !',
#  '「 歯 \u3000 磨け よー 」 「 宿題 しろ よー 」 「 気 を つけ て 帰れ よー 」',
#  '「 いい 夢みろ よー 」 「 お 父 さ ー ん 」',
#  '「 他 の 現場 も 行け よー 」 「 風邪 ひく な よー 」 「 チョット だけ よー 」',
#  '「 ファイト いっ ぱ ー つ 」 「 物販 も よろしく ー 」',
#  '永遠 に 中学生 !',
#  '「 みなさま \u3000 ごきげんよう !!」',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  'ねぇ さっき 全然 興味 が ない って 言っ て た のに',
#  'どうして み て ん の ?   周辺 視覚 で',
#  'セクシー 仙人',
#  'カンフー 万 人',
#  '今 は もはや パンダ な 気分 ( き もち ) の 三 人',
#  'そんな まさか',
#  'Holiday',
#  'ちく わ ぶ くわえ ながら 柔軟 体操',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  '友人 と ベンチ',
#  '最高 の ランチ',
#  '最初 の 3 年 の 記憶 は 白紙',
#  '気さく に JUMP !!',
#  '町 へ 続く 道 と 逆 の 道',
#  '身振り 手振り で 渡れる 世界',
#  'オーロラ',
#  'かまぼこ の 味 が する アジア の グルメ',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  '君 が 桟橋 の 向こう 側 から',
#  '一所懸命 手 を 振る 姿 が',
#  '背後 の 背景 に なじみ',
#  '僕 は いつのまにか 空 を かじり',
#  '枯れ は の 日々 を くぐり抜け て',
#  '気まぐれ Rally - Ho',
#  '君 が 桟橋 の 向こう 側 から',
#  '一所懸命 手 を 振る 姿 が',
#  '背後 の 背景 に なじみ',
#  '僕 は いつのまにか 空 を かじり',
#  '枯れ は の 日々 を くぐり抜け て',
#  '気まぐれ Rally - Ho',
#  'ちゃんばら おやじ と お ばあちゃん',
#  '頭 から 血 流し てる こりゃ いかん',
#  'チンピラ イライラ   疎外 感',
#  'お 肌 つるつる する の か な ? 白湯',
#  'メロス の 泉 を 探し て',
#  '北 、 南 、 東 、 西   羽ばたい て',
#  'たま に は 大胆 か まし て   いま',
#  '突撃 いたし ます る よ',
#  '突撃 いたし ます る よ',
#  '突撃 いたし ます る よ',
#  '',
#  'おばけ   おばけ   おばけ が くる ぞ !',
#  'に げろ   にげろ   追いつか れる ぞ !',
#  'やばい   やばい   取り 憑かれる ぞ !',
#  'ぎゃ ーーーーー !',
#  '真夜中   真夏 に   マジ でき も だ めし',
#  '夏 だ と いう のに   なに よ   この 寒気 ｡｡｡',
#  'おばけ とか   いる わけ ない しっ !',
#  '何 より も   科学 的 じ ゃないっっ !',
#  '白い 服   ずぶ ぬれ の 髪',
#  '笑っ てる   あの 人 は   誰 な の !?',
#  '臨 ・ 兵 ・ 闘 ・ 者 ・ 皆 ・ 陣 ・ 列 ・ 在 ・ 前',
#  'って ぜんぜん   効か ない じゃん !!',
#  'お じゅず',
#  'だめ だ こりゃ',
#  '囲ま れ ちまっ た',
#  '戦う しか ない',
#  '',
#  'ワーオ   ワーオ   ワオ   ワーーオ',
#  'そ ー めん',
#  'ひやそ ー めん !',
#  'はい !',
#  'それ ! それ ! それ ! それ !',
#  'それ ! それ ! それ ! それ !',
#  '',
#  '幽霊 なんか   ぶっとばせ !!',
#  '延髄 蹴り で   けっとばせ !!',
#  '女の子 を   なめ ない で !!',
#  'ママ の 方 が   よっぽど 怖い わ',
#  'ゴースト なぞ   ぶっとばせ !!',
#  'せ いけん 突き で   ふっとば せ !!',
#  'ケンカ 上等   負け ない ぜ !!',
#  'たたる 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  'エビ 中   ゴーストバスターズ',
#  '',
#  'ゾンビ   ゾンビ   ゾンビ も き た ぞ !',
#  'に げろ   にげろ   追いつか れる ぞ !',
#  'やばい   やばい   噛み付か れる ぞ !',
#  'ぎゃ ーーーーー !',
#  '部活 の 帰り   真っ暗   8 時 過ぎ',
#  '近道   小道   抜け道   外人 基地',
#  '曇り空   急 に 雷',
#  '真っ 二つ   ケヤキ が 割れる',
#  'もぞもぞ と   ゾンビ が 動く',
#  '',
#  'あり え ない っ !!   夢 か 幻 だ わ ｡｡｡',
#  "Oh   my   God !   Why   don ' t   you   save   me   new ?",
#  'って 英語 通じ ます かぁ ?',
#  'ドロドロ',
#  'ぐちゃぐちゃ',
#  'だめ だ こりゃ',
#  '逃げ場 ふさが れ た',
#  'やっ ちゃ い ましょ う か',
#  'ワーオ   ワーオ   ワオ   ワーーオ',
#  'あー ぶら   かた ぶら   びばのんのん !!',
#  '',
#  'ゾンビ なんか   ぶっとばせ !!',
#  '飛び ひざ 蹴り で   けっとばせ !!',
#  'ニッポン 女子   なめ ない で !!',
#  '先生 の 方 が   よっぽど 怖い わ',
#  'アン   ドュー   トロ ワ ☆   で   ぶっとばせ !!',
#  'ラリアット で   ふっとば せ !!',
#  '百戦錬磨   負け ない ぜ !!',
#  '襲う 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  '今夜 は スリラー   スリラー ナイト',
#  'アーメン',
#  'そ ー めん',
#  'ひやそ ー めん !',
#  'はい !',
#  'それ ! それ ! それ ! それ !',
#  'それ ! それ ! それ ! それ !',
#  '幽霊 なんか   ぶっとばせ !!',
#  '延髄 蹴り で   けっとばせ !!',
#  '女の子 を   なめ ない で !!',
#  'パパ の 方 が   ある 意味 怖い わ',
#  'ゴースト なぞ   ぶっとばせ !!',
#  'せ いけん 突き で   ふっとば せ !!',
#  'ケンカ 上等   負け ない ぜ !!',
#  'たたる 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  'エビ 中   ゴーストバスターズ',
#  'いつか 語り合っ た 想い を 抱え',
#  '約束 の 場所 たどり着く まで',
#  '強がる ほど に 涙 は 溢れ',
#  '永遠 じゃ ない 今 が 始まる',
#  '止まら ない で \u3000 胸 の 奥',
#  'しまい こん だ \u3000 色とりどり の 光',
#  '忘れ ない よう に 進め ば いい',
#  'Wow   Wow   Wow',
#  'ねぇ \u3000 信じ て',
#  '笑え ない 日 だって ある けど',
#  '君 の 全て が 明日 を てらす から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  '抱え きれ ない ほど の 願い事',
#  '全て が 叶わ ない の 分かっ てる',
#  'それでも 手 を 引い て くれる 君 が いる から',
#  'また 歩き 出せる よ',
#  'いつも どおり に',
#  '笑い あっ た \u3000 いくつ も の',
#  '思い出 や \u3000 切ない 痛み も',
#  '忘れ ない よ \u3000 この 空 に 色 を 添え て',
#  'Wow   Wow   Wow',
#  'ねぇ \u3000 信じ て',
#  'こぼれ そう な 涙 拭う 手',
#  '君 の ぬくもり',
#  'すべて 知っ てる から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  '曖昧 な 日々 を 繋い でる',
#  '長く 続く 足跡',
#  'どこ まで 続く だろ う',
#  'どこ まで 行ける だろ う',
#  '確か な こと は 何 も ない けど',
#  '怖く ない',
#  '止まら ない で \u3000 胸 の 奥',
#  'しまい こん だ \u3000 色とりどり の 光',
#  '忘れ ない よう に 進め ば いい',
#  'Wow   Wow   Wow',
#  'ねぇ \u3000 信じ て',
#  '笑え ない 日 だって ある けど',
#  '君 の 全て が 明日 を てらす から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  'Say   Yeah   Say   Yeah',
#  'さあ 、 Say   Yeah   Say   Yeah',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '声 を 出し て よ',
#  'Hey ！ \u3000 加速 する DAYS \u3000 加熱 する BODY',
#  '私 の 愛 \u3000 受け取れ ない ？   ( イイ ヨー ！ ！)',
#  '青二才 \u3000 でも この 際',
#  '火遊び し て みる ？   By   my   side',
#  'Time   goes   by \u3000 磨け ば 輝く っしょ \u3000 いける っしょ ！',
#  'そんな エモ め の 土曜 も Change   up',
#  'ちょっと サビ まで stay   up',
#  '大器晩成 さ',
#  'これから もっと 輝い て ゆく の',
#  '愛 と 正義 さ',
#  'ブチ か ます から つい て き て',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ \u3000 さあ   SHAKE ！   SHAKE ！',
#  'ハイ ！ \u3000 格好 の STUDY \u3000 思考 の SWAY',
#  '楽しく ない なら 用 は ない',
#  '本日 は 膝 上 20 cm (！？)',
#  'でも 無敵 の 私 は 怯ま ない',
#  '髪 も バッチリ \u3000 でも 少し Chilly',
#  '何 も 知ら ない から 終われ ない',
#  '純情 ・ 友情 ・ バカ 参上 ( ハァーイ ！！)',
#  'まだ 知ら ない 天井',
#  '絶体絶命 の',
#  '状況 も もっと 楽しん で ゆく の さ',
#  '笑止千万 さ',
#  'かっ飛ばす から つい て き て',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ \u3000 今   SHAKE ！   SHAKE ！',
#  'HEY ,   GUYS ！   BOYS   AND   GIRLS',
#  '今 から 言う こと よく 聞き な',
#  '命 の 限り 手 挙げろ',
#  'つい て こ れる やつ は つい て 来い',
#  '私 たち の 姿 よく 見 とけ',
#  '半端 な やつ は 今 帰り な',
#  'さあ 、 いけん の か ？ \u3000 やれん の か ？',
#  '分かっ た やつ は 返事 しろ',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ \u3000 ほら ！   SHAKE ！   SHAKE ！',
#  '',
#  '放課後   ど しゃぶり の 雨 の 中 で',
#  '傘 も ささ ず 立ちすくむ',
#  '彼女 と 彼 が 付き合っ てる こと',
#  '初めて 聞い て しまっ た',
#  '',
#  '入学 式 から 今日 まで ずっと',
#  '隠し て い た この 気持ち',
#  '',
#  '誰 に も ゆずる わけ に いか ない と',
#  '心 に 決め て た のに',
#  '',
#  '｢ 彼 の こと が 好き   応援 し て よ ね !!｣',
#  '( セリフ )',
#  '｢ 彼 の こと が 好き な ん だ   応援 し て くれる よ ね ?｣',
#  '突然   打ち明け られ た あの 日',
#  '友情   愛情   選ぶ こと 出来 なく て',
#  '作り笑い',
#  'し て い た   REGRET !!',
#  '',
#  '泣け ど 叫べ ど   戻せ ない   Destiny',
#  'こんなに   好き な のに   想い は 届か ない',
#  '流す 涙 が   雨 に 消え て いく',
#  '二 人 の 幸せ を   永遠 に 祈る よ',
#  "I   Love   you   でも   It ' s   Too   Late",
#  '嗚呼   ど しゃぶり リグレット',
#  '',
#  '放課後   ど しゃぶり の 雨 の 中 で',
#  '肩 寄せ あい 歩い てる',
#  '周り も 見え ない   二 人 の 世界',
#  '憧れ の 相合傘',
#  '',
#  'ふざけ て じゃれ あう   彼 と 彼女 の',
#  '見 た こと ない その 笑顔',
#  '',
#  'ほんと なら 私 が すぐ 隣 で',
#  '笑っ て た はず な のに',
#  '',
#  '｢ 私 も 好き な の   負け ない ん だ から !!｣',
#  '( セリフ )',
#  '｢ 私 も 好き な の ! 負け ない ん だ から !!｣',
#  '素直 に 言え たら よかっ た のに',
#  '勇気 が 足り ず に 気持ち ごまかし て たら',
#  '愛情 も',
#  'なくし た   REGRET !!',
#  '',
#  '寝 て も 覚め て も   止まら ない 涙',
#  '神様   教え て よ   夢 は 叶わ ない の ?',
#  'もしも 時間 を   戻せる の なら ば',
#  'あなた へ この 想い   全身 で 届けよ う',
#  "I   Love   You ・ ・ ・   You   Don ' t   Love   Me .",
#  '嗚呼   ど しゃぶり リグレット',
#  '初めて いだい た 恋心',
#  '忘れ られる わけ が ない じゃ ない',
#  'この 胸 の 痛み 思い出 に   変わる の か な',
#  '嗚呼   雨 が やま ない よ',
#  '',
#  '泣け ど 叫べ ど 戻せ ない   Destiny',
#  'こんなに 好き な のに   想い は 届か ない',
#  '',
#  '流す 涙 が   雨 に 消え て いく',
#  '二 人 の 幸せ を   永遠 に 祈る よ',
#  "I   Love   You   でも   It ' s   Too   Late",
#  '嗚呼   ど しゃぶり リグレット',
#  'ドン どど ・ どん どど ・ ドーン っ ！',
#  '打ち上げろ 花火',
#  '寝 て も 覚め て も',
#  '終わら ない ジャンボリー',
#  'なぜ そこ まで と わけ わから ん ほど の \u3000 汗 と 努力 で',
#  '掘り出し物 の 夢 を 磨き 上げ \u3000 ここ まで き た',
#  'ちょっと 待っ て \u3000 あっ ため た',
#  'ヴォンゴレー ！ \u3000 食べる から',
#  '銀河系 中 \u3000 同時 進行 \u3000 頭上 げろ ！',
#  '土星 の 輪っか な 街 で \u3000 君 と スウィーテスト な 多忙',
#  'ここ で 会っ た が 百 年 目 ね \u3000 組ん ず 解れ つ',
#  '25 . 6 時間 じゃ 足り ない',
#  '水金 地 火 木 な エヴリデイ',
#  '君 と 出会え た 奇跡 に',
#  'ナ・ナ・ナ・ナ・ナ・ナ・ナ・ナ・ナマステ ！ ナマ ステ ！',
#  'ワオ ！',
#  'ダイヤモンド が 眠る 国 が ある \u3000 行っ て み たい な',
#  'オイミヤコン 村 は 、 マイナス 71 度 \u3000 めっちゃ 寒い ！',
#  'テン ガロン で バンガロー に',
#  'ボンソワール ！ \u3000 叶う まで',
#  '頑張ろ う ぜ 皆 、 バンジョー ！ \u3000 かき鳴らし て ！',
#  'トロピカル な 水着 で   Yes ！ ！ \u3000 君 と スウィーテスト な 多忙',
#  'ナビ も つけ ず に 回り道 で \u3000 全部 想い出',
#  '土星 の 輪っか な 街 で \u3000 君 と スウィーテスト な 多忙',
#  '月 の 光 に 溶け た ぼく ら \u3000 歌う 都々逸 ！',
#  '音楽 室 の 壁 に \u3000 飾ら れ た 肖像 画',
#  '一 人 だけ 校長 先生 に',
#  '似 てる の が ド・ド・ド・ド・ドビュッシー ！ ドビュッシー ！',
#  'ワオ ！',
#  'ドン どど ・ どん どど ・ ドーン っ ！',
#  '打ち上げろ 花火',
#  '寝 て も 覚め て も',
#  '終わら ない ジャンボリー',
#  'ゴー ！ Ready \u3000 ゴー ！ Ready \u3000 ゴー っ ！',
#  '共に 行こ う ！ \u3000 未だ 見 ぬ 世界 へ ！',
#  'ゴー ！ Ready \u3000 ゴー ！ Ready \u3000 ゴー っ ！',
#  'いざ 、 君 と',
#  'スウィーテスト・ 多忙 な デイズ ！',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '恵比寿 駅 発 の 土星 行き',
#  '加速度 ぐんぐん 上げ ましょ う',
#  'テスト の 範囲 は 小宇宙',
#  '居残り 確定 明日 の 授業',
#  'ゆらゆら ゆらゆら 流れ着き',
#  '今日 も 宿題 は 後回し',
#  '水金 地 火 木 土 天海 ( 冥 )',
#  '放課後 カラオケ \u3000 よそ の 惑星',
#  'あぁ 麗し の ブラウニー',
#  '( ひとつ \u3000 ふたつ \u3000 もう 止まら ない )',
#  'あれれ ？ \u3000 ちょっと もしか し たら',
#  'カロリー オーバー じゃん ？ ！',
#  '( 甘い もの なら 別 次元 )',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '地球 は どうやら 忙しい',
#  'ハイファイワイファイ もう いっぱい',
#  '明治 大正 昭和 平成',
#  '文明開化 の 音 が する',
#  'あぁ \u3000 追憶 の フィナンシェ',
#  '( もっと キミ の 声 聞か せ て よ )',
#  'ちょっと ！ \u3000 すぐ に 交信 する の やめ て よ 火星 人',
#  '( ぴぴぴぴぴぴぴぴぴぴぴぴ )',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '夜 の クラブ ビジョン \u3000 潜め た   Rainbow   Gray に',
#  '遠ざかる デジャブ と \u3000 近づく \u3000 夏 の 鼓動',
#  'もう \u3000 切ない ほど \u3000 燃え だそ う と し てる の',
#  'いつか ら か \u3000 時めい て \u3000 何気ない 日常 まで',
#  'シングル TONE で お願い \u3000 「 好き 」 の 響き が 聞き たく て',
#  'ノイズ さえ も ハモ り だす 予感 が する の よ',
#  'シングル TONE で お願い \u3000 過去 も これから も 刻み だす',
#  '雨 音 に \u3000 まどろん で \u3000 二 人 の 未来 回り だす',
#  'ふい に すれ違っ た \u3000 心 の 行方 さえ',
#  'その 素振り 隠し て \u3000 あなた は \u3000 目 を そらす',
#  'ほら \u3000 いつのまにか \u3000 二 人 を 繋げ て く',
#  '当たり前 に \u3000 流れ て く \u3000 何気ない 日常 から',
#  'シングル TONE で お願い \u3000 儚く 砕け そう な \u3000 ハーモナイズ',
#  'あなた と は 突き抜ける 予感 が する の よ',
#  'シングル TONE で お願い \u3000 胸 の 隙間 から 弾け 飛ぶ',
#  'いつか ら か \u3000 時 を 超え て \u3000 二 人 は 未来 作りだそ う',
#  '大好き な 理由 を \u3000 簡単 な 言葉 で 伝え たい',
#  'そう \u3000 私 を \u3000 信じよ う',
#  'シングル TONE で お願い \u3000 「 好き 」 の 響き が 聞き たく て',
#  'ノイズ さえ も ハモ り だす 予感 が する の よ',
#  'シングル TONE で お願い \u3000 過去 も これから も 刻み だす',
#  '雨 音 に \u3000 まどろん で \u3000 二 人 の 未来 回り だす',
#  'なんて 切ない ん だろ う \u3000 時間 が 出し た 答え が \u3000 胸 を 締め付ける',
#  'おはよう の 声 と \u3000 頭 に ポ ン と 置か れ た 手 は 大人 の 香り が し てる 気 が し た',
#  '教室 の 窓 \u3000 いつも 見 て た あなた は \u3000 きっと 今 も 気づい て ない よ',
#  'さようなら \u3000 春 が 近づい て あなた に 会え なく なる ん だ ね',
#  '伝え たい \u3000 この 気持ち だけ が ずっと 言え ない まま でし た',
#  '本当は すごく 寂しい ん だ よ \u3000 ほら ね すぐ に 涙 が 溢れ た',
#  'なんて 切ない ん だろ う \u3000 当たり前 の 毎日 が \u3000 変わっ ちゃう みたい だ',
#  '放課後 の 度 に \u3000 探し まわっ た 廊下 は もう 思い出 の 色 に 深く 染まっ た',
#  '二 人 で 歩く 時間 も 無くなる 事 \u3000 想像 すら も し て い なかっ た',
#  'さようなら \u3000 叶わ ない 恋 と 知っ て も 想い 続け てる',
#  '伝え たい \u3000 この 気持ち だけ は 最後 まで 言え ない まま で いい',
#  'あの 笑顔 思い出す 度 に \u3000 胸 の 奥 が チクリ と 疼い た',
#  '優しい 記憶 消え ない よう に',
#  '哀しみ だけ を ぎゅっと 胸 に 閉じ込め た なら',
#  '前 だけ を 向い て 行ける ？',
#  'さようなら \u3000 いつか 話す よ \u3000 その 時 まで',
#  '帰り道 \u3000 一 人 で そっと つぶやく 「 好き だ よ 。 きっと それでも 」',
#  'さようなら \u3000 春 が 近づい て あなた に 会え なく なる ん だ ね',
#  '伝え たい \u3000 この 気持ち だけ が ずっと 言え ない まま でし た',
#  '本当は すごく 寂しい ん だ よ \u3000 ほら ね すぐ に 涙 が 溢れ た',
#  'せめぎ あう \u3000 せめぎ あう',
#  'ざわざわ',
#  'せめぎ あう \u3000 せめぎ あう',
#  '心 が',
#  'せ ・ め ・ ぎ ・ あ ・ う',
#  '春休み モラトリアム 中学生',
#  'こ いっ ！ ！   こ いっ ！ ！   ゾッコン ！ ！',
#  'こ いっ ！ ！   こ いっ ！ ！   ロックオン ！ ！',
#  '心 の 筆箱 ガタガタ 落ち着か ない',
#  '授業 中 だって ギリギリ 見つめ てる',
#  'すれ違う 視線 \u3000 希望 が 反比例',
#  '未だ 答え 「 Y ＝ X 」 の まま',
#  'この 気持ち まるで 素数 \u3000 に ー さん ご ー な な ！ ！',
#  '絶対 に 割り切れ ない よ',
#  'え た にて ぃ ー',
#  '秘密 の 方程式',
#  '私 だけ に こっそり と 耳打ち し て',
#  '素っ気 ない 態度',
#  'そっぽ 向い ちゃっ て',
#  '好き の 裏返し ？ ！',
#  '超 前向き ！ ！',
#  '恋 の 面積 \u3000 君 と 二 人 \u3000 証明 し て み たい',
#  'せめぎ あう \u3000 せめぎ あう',
#  'ぞくぞく',
#  'せめぎ あう \u3000 せめぎ あう',
#  '妄想 ！ ！',
#  'せ ・ め ・ ぎ ・ あ ・ う',
#  'い て も たっ て も い られ ない',
#  'もどかしい 感情 × 100   ゾッコン ！ ！',
#  'みっともない ほど 君 に 夢中',
#  '宙ぶらりん の ハート どうし よう \u3000 やる だけ やっ ちゃ え',
#  '伝え たい けど 伝え られ ない',
#  'もたもた し て たら 先 越さ れ ちゃう \u3000 ソッコー ！ ！',
#  '嗚呼 、 悔しい けど ゾッコン な ん だ もん',
#  '桜 \u3000 散っ てる 場合 じゃ ない から',
#  '春休み 直前',
#  'モラトリアム \u3000 モラトリアム \u3000 モラトリアム 中学生',
#  '放課後 ゲタ 箱 \u3000 不意 に 君 が 現れ た',
#  '何 も 言え ない \u3000 ちゃんと \u3000 バイバイ \u3000 し たかっ た',
#  'この 気持ち まるで 素数',
#  'に ー さん ご ー な な ！ ！',
#  '絶対 に 割り切れ ない よ',
#  'え た にて ぃ ー',
#  '新 学期 \u3000 どぉ なっ ちゃう ん だろ',
#  '何 が なん でも 君 と 同じ クラス が いい',
#  '机 くっつけ て',
#  '教科書 忘れ た ぁ ～！！',
#  '面 と 向かっ て',
#  '集中 無 理っ ！ ！',
#  '居残り 授業 \u3000 君 と 二 人 \u3000 答え 合わせ を し たい',
#  'せめぎ あう \u3000 せめぎ あう',
#  'ざわざわ',
#  'せめぎ あう \u3000 せめぎ あう',
#  '葛藤 ！ ！',
#  'せ ・ め ・ ぎ ・ あ ・ う ・ せ ・ め ・ ぎ ・ あ ・ う',
#  'い て も たっ て も い られ ない',
#  'もどかしい 感情 × 100   ゾッコン ！ ！',
#  'みっともない ほど 君 に 夢中',
#  '宙ぶらりん の ハート どうし よう \u3000 やる だけ やっ ちゃ え',
#  '伝え たい けど 伝え られ ない',
#  ...]

# %%
# dataprocess
from txt2txt_ebc import data_process
df = data_process.to_df("../data/raw/ebc/*.txt")
df.shape
# Out:
# (6592, 3)

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer()
def gen_wakati_txt(txt: str):
    return ' '.join(t.tokenize(txt, wakati=True))
df['wakati_line'] = df['line'].apply(gen_wakati_txt)
sentences = df['wakati_line'].tolist()
sentences
# Out:
# まっ た 事',
#  '返し て くれる なら',
#  '愛し て みせる のに',
#  '愛し て い たい の に 消え て なくなっ て しまう な',
#  'やめ られ ない よ',
#  '感情 的 に はなれ ない 君 は 僕 と 踊れ ば いい',
#  'ずっと 僕 と ！',
#  '愛し て い たい の に 消え て なくなっ て しまう な',
#  '手 に 負え ない ぜ',
#  '最終 的 に 笑え ない 君 も 僕 も 踊れ ば いい',
#  'ずっと 僕ら 踊れ ば いい',
#  'silver   body   to   ride',
#  'digital   rock   &   roll   tune',
#  'baby   baby   baby',
#  'you   are   new - animal',
#  'heavy   metalic',
#  'digital   summer   beach',
#  'baby   baby   baby',
#  "I   don ' t   know   everything !!   all !!",
#  'do   mo   a   ri   ga   to   baby',
#  'bo   ku   ra   no   se   i   shu   n',
#  'do   i   ta   shi   ma   shi   te   baby',
#  'bo   ku   ni   ma   ka   se   na   yo',
#  'super   psychic',
#  'sun   sun   sun   sun   sun   ...',
#  'baby   island',
#  'ge   -   ge   -   generation   X',
#  'do   mo   a   ri   ga   to   baby',
#  'bo   ku   ra   no   se   i   shu   n',
#  'do   i   ta   shi   ma   shi   te   baby',
#  'bo   ku   ni   ma   ka   se   na   yo',
#  'do   ko   ma   de   to   be   ru   ka',
#  'te   a   shi   wo   po   no   po   no',
#  'so   n   na   ko   n   na   " a   ri   ga   to "',
#  'ki   mi   wa   bo   ku   no   mo   no',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  '｢ 90 ｣｢ 91 ｣｢ 92 ｣｢ 93 ｣｢ 94 ｣｢ 95 ｣｢ 96 !!｣',
#  "bye   bye ('   o   '   )",
#  'チェケラッチョ',
#  'YO   DJ',
#  '何故か 鳴ん なかっ た アラーム',
#  '開か ず 踏切 閉まる ドア',
#  '何故か 上がん ない ウダツ',
#  '分かん ない 英文 ギブ し て 、 sleeping   sleeping',
#  '夢 の 中 なら ほら',
#  'かなり 無茶 め な シナリオ も',
#  'したい 放題 だっ た のに',
#  'ガ ツン おでこ に チョーク が 飛ん で き た',
#  '根拠 は 無い けど 大声 で 歌え ば 晴れる や',
#  'ただ で さえ 蒸し暑い 毎日',
#  'ハート ウォーミング は お呼び じゃ ない',
#  'いつの間にか やぶれ 捨て た 無 遅刻 無 欠席 スローガン',
#  'そん 代わり 大 親友   and   take   care   see   you   放課後 に また',
#  '居眠り ほっぺ の 跡 で トピック 話題 を さらお う',
#  '照り付ける 日差し 教室 は もう ちょっと で ブラジル',
#  'はじまり は ブラジル',
#  'おおかた ブラジル',
#  'YO   DJ',
#  '上書き さ れ て いく 最高 気温',
#  '反比例 下がる やる気 が どんどん',
#  'し た たた たる 汗 炭酸 飲み た ひ',
#  '干からび た ミミズ マジ に シンパシー',
#  'いち おく よん せん きゅう ひゃく メートル',
#  '太陽 発 校庭 経由 私',
#  '着 慣れ た 夏服 に ため息 ひとつ',
#  'A . S . A . P チャイム !',
#  '意味 なんて 無い けど それでも 今日 も 走る よ',
#  'ただ で さえ バテバテ の 季節 に',
#  'ハート ウォーミング は お呼び じゃ ない',
#  '下駄 箱 の 奥 の 方 に 忘れ て た 無 欠席 スローガン',
#  'そん 代わり 大 親友   and   take   care   see   you   放課後 に また',
#  '宿題 は ご飯 の 後 で メール 打ち ながら ゴロゴロ',
#  'とか 言い つつ も 明日 は プール アリ おおよそ ブラジル',
#  '三 段 重ね アイスクリーム',
#  '扇風機 に 向かっ て スクリーム ( A ” h ” h ” h ” h ” h ” )',
#  '蚊 に 刺さ れ て マジカチン',
#  '頭 突き の ひとつ でも か まし て やり たい',
#  'いつの間にか やぶれ 捨て た   無 遅刻 無 欠席 スローガン',
#  'そん 代わり   大 親友   and   take   care   see   you   放課後 に また',
#  '居眠り ほっぺ の 跡 で   トピック 話題 を さらお う',
#  '照り付ける 日差し   そこ どこ   ここ どこ   こりゃ ほぼ ブラジル',
#  'ほぼ ほぼ ブラジル',
#  'となり は コロンビア',
#  '君 と 僕 の あの 日々 が',
#  'いつも 強く つながっ てる よ',
#  'アイムサーチング   アイムサーチング',
#  'この 先 の 光 に   向かっ て ゆく なら',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '海底 に 潜む   シーラカンス',
#  'ゆっくり と 進化   照らし 出す',
#  '神 が いる として も   い ない として も',
#  '止め たく ない ん だ   僕ら の ストーリー',
#  'アイムサーチング   アイムサーチング',
#  '共に この 想い   あたため て ゆく から',
#  'PLAYBACK   PLAYBACK',
#  '願 わく ば   今 は そば に い て',
#  'PLAYBACK   PLAYBACK',
#  '生まれ変わっ て も   そう 君 の まま で い て',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '再生',
#  '感じとれる   この 先 の 光   見 に 行こ う',
#  'PLAYBACK   PLAYBACK',
#  '願 わく ば   今 は そば に い て',
#  'PLAYBACK   PLAYBACK',
#  '大人 に なっ て も   そう 君 の まま で い て',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  'Uuu',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  '新しい 季節 巡り',
#  '揺るぎない この 想い',
#  '窓 を 開け たら すぐ に',
#  '君 の もと へ 飛び込む よ',
#  '始めよ う 今 この 場所 で',
#  'メラメラ 燃やす 想い',
#  'はち切れ そう な 憂鬱 に',
#  'ハッピー な クラッカー 打ち込ん で',
#  'ねぇ 言葉 じゃ 照れ ちゃう よ',
#  'ごまかし ちゃい そう で',
#  'ねぇ その 手 を 握り',
#  'ステージ に 立っ て 奏でよ う',
#  'あぁ 今 は この リズム に 乗っ て',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '数え て み ましょ 羊 さん',
#  'あっち の 夢 は 見る けど',
#  'こっち の 夢 を 叶える の',
#  '今 すぐ 全 速 前進 で',
#  'ねぇ 涙 が 溢れ て',
#  '濡らし た あの 日',
#  'ねぇ 宝物 に なっ て',
#  'この 背中 を 押し て くれる',
#  'あぁ 今 も この リズム に ノ って',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '「 私 もう 迷わ ない ！   みんな ー いく よっ ！ 」',
#  'Kick   and   punch   で   We   win ！',
#  'Chop   and   stick   で   Eat   in ！',
#  'Kick   for   kick   は   Win - win ！',
#  'チャンス は どこ ？   Checking ！',
#  '見つけ て   Getting ！',
#  'Big   wave 到来   Swimming ！',
#  'あぁ あの 頃 の 私 たち は きっと',
#  '大切 な 事 を 見失っ て い た ね',
#  'あぁ これから は 誰 に も 負け ない よ',
#  'あなた が くれ た 魔法',
#  '光 の 挿す 方 へ と',
#  'あぁ 今 は この リズム に 乗っ て',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら   ほら   hot   up ！ ！ ！',
#  'さあ さ みんな よっ て らっしゃい 小麦 ふっ て パン パンパン',
#  '揚げる ん だ エビ フライ どんと 行っ ちゃっ て',
#  'エビ に 恋せよ 乙女 でっかい でっかい の 大好き',
#  '洋食 の 王様 だ ワオ !',
#  '( サクサク 揚げろ 揚げろ 揚げろ )',
#  'ゴクリ 舌なめずり ( ゴクリ )',
#  'みんな テンション 上げ 上げ ( 上げ 上げ )',
#  'パーティー ムード なんか いい ぞ !',
#  'それ っ い !',
#  '( え ～ じゃ ない ええ じゃ ない じゃ ない )',
#  'ロブスターオマールエビ 浮気 し ちゃい そう',
#  'でも 君 に 一途 だ よ',
#  'サクサクプリプリプリ',
#  'パリパリカリカリカリ',
#  'なんて なんて 美味しい の 早く 早く フライ !',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'エビ フライ 揚げろ 揚げ 揚げ ジュワジュワジュワ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと テンション',
#  'グイグイグイ 上げ て',
#  '挙げ 挙げ 挙げ 挙げ 挙げ 挙げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケングー !( あいこ ～!)',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  'オードブル で 主役 フライ 級 の チャンピオン',
#  '学園中 人気 沸騰 ワオ !',
#  '( テンション 上がる 上がる 上がる )',
#  '熱い 油 の 中 ( あ ち ゅい )',
#  'なんて 君 は たくましい ( たくましい )',
#  '愛し てる でも 食べ ちゃう ぞ !',
#  '( え ～ じゃ ない ええ じゃ ない じゃ ない )',
#  '焼い ちゃ ダメ 煮 て も ダメ もっと 美味しく し て',
#  'こんがり と キツネ 色',
#  'サクサクプリプリプリ',
#  'パリパリカリカリカリ',
#  'サクサクプリプリプリエビエビエビフライ',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  'エビ フライ 高く 高く 高く フライフライフライ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと もっと',
#  'サクサク サク 揚げ て',
#  '挙げ 挙げ 挙げ 挙げ 挙げ 挙げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケンチョキ !( 負け た !)',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  '大好き ～ ジュワ ～ 美味しい ～',
#  '揚げ て 上げ て 揚げ て 上げ て',
#  '揚げ て 上げ て 揚げ て 上げ て',
#  '真っ黒 け っけ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'エビ フライ 揚げろ 揚げ 揚げ ジュワジュワジュワ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと テンション',
#  'グイグイグイ 上げ て',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケン パー !( 勝っ た ～!)',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  'さあ さ みんな よっ て らっしゃい 小麦 ふっ て パン パンパン',
#  '揚げる ん だ エビ フライ 全部 食べ ちゃっ て !( ジュワ ～)',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'お ばあちゃん だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  '高校生 だって 中学生',
#  'いつ でも   ( いつも )   こうして   ( みんな )',
#  'バカ みたい に 遊ん で たい な',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'ヲタ さん だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'スタッフ さん も 中学生',
#  'ずーっと ね   ( ずーっと )   みんな と   ( ここ で )',
#  '今 の まんま 笑お う ね !',
#  'ほら 聞こえ て き まし た 下校 の ベル です',
#  '本日 これ にて おしまい',
#  '忘れ物 せ ず に 帰り ましょ',
#  '少し さみしい な 下校 の ベル です',
#  'また 次回 お 逢い し ましょ う',
#  '恵比寿 中学 で 永遠 に 中学生 !',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'いくつ だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  '気分 次第 中学生',
#  'どんなに   ( いつか )   大きく   ( なっ て も )',
#  'この 気持ち 忘れ ない',
#  'せ ー の',
#  'キンコンカンコンキンコンカンコン 下校 の ベル です',
#  '初心 忘れる べから ず',
#  '全然 エラく も ない です が',
#  'おわり の おしらせ 下校 の ベル です',
#  '次 の 登校 日 い つ でしょ ね',
#  'ホームページ チェック し て ね 永遠 に 中学生 !',
#  '今日 は 来 て くれ て ほんとに ありがとう !',
#  'ありがと !',
#  '聞こえ て き まし た 下校 の ベル です',
#  '本日 これ にて おしまい',
#  '忘れ物 せ ず に 帰り ましょ',
#  '少し さみしい な 下校 の ベル です',
#  'また 次回 お 逢い し ましょ う',
#  '恵比寿 中学 で 永遠 に 中学生 !',
#  '「 歯磨 け よー 」 「 宿題 しろ よー 」 「 気 を つけ て 帰れ よー 」',
#  '「 いい 夢みろ よー 」 「 お 父 さ ー ん 」',
#  '「 他 の 現場 も 行け よー 」 「 風邪 ひく な よー 」 「 チョット だけ よー 」',
#  '「 ファイト いっ ぱ ー つ 」 「 物販 も よろしく ー 」',
#  '永遠 に 中学生 !',
#  '「 みなさま ごきげんよう !!」',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  'ねぇ さっき 全然 興味 が ない って 言っ て た のに',
#  'どうして み て ん の ?   周辺 視覚 で',
#  'セクシー 仙人',
#  'カンフー 万 人',
#  '今 は もはや パンダ な 気分 ( き もち ) の 三 人',
#  'そんな まさか',
#  'Holiday',
#  'ちく わ ぶ くわえ ながら 柔軟 体操',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  '友人 と ベンチ',
#  '最高 の ランチ',
#  '最初 の 3 年 の 記憶 は 白紙',
#  '気さく に JUMP !!',
#  '町 へ 続く 道 と 逆 の 道',
#  '身振り 手振り で 渡れる 世界',
#  'オーロラ',
#  'かまぼこ の 味 が する アジア の グルメ',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  '君 が 桟橋 の 向こう 側 から',
#  '一所懸命 手 を 振る 姿 が',
#  '背後 の 背景 に なじみ',
#  '僕 は いつのまにか 空 を かじり',
#  '枯れ は の 日々 を くぐり抜け て',
#  '気まぐれ Rally - Ho',
#  '君 が 桟橋 の 向こう 側 から',
#  '一所懸命 手 を 振る 姿 が',
#  '背後 の 背景 に なじみ',
#  '僕 は いつのまにか 空 を かじり',
#  '枯れ は の 日々 を くぐり抜け て',
#  '気まぐれ Rally - Ho',
#  'ちゃんばら おやじ と お ばあちゃん',
#  '頭 から 血 流し てる こりゃ いかん',
#  'チンピラ イライラ   疎外 感',
#  'お 肌 つるつる する の か な ? 白湯',
#  'メロス の 泉 を 探し て',
#  '北 、 南 、 東 、 西   羽ばたい て',
#  'たま に は 大胆 か まし て   いま',
#  '突撃 いたし ます る よ',
#  '突撃 いたし ます る よ',
#  '突撃 いたし ます る よ',
#  '',
#  'おばけ   おばけ   おばけ が くる ぞ !',
#  'に げろ   にげろ   追いつか れる ぞ !',
#  'やばい   やばい   取り 憑かれる ぞ !',
#  'ぎゃ ーーーーー !',
#  '真夜中   真夏 に   マジ でき も だ めし',
#  '夏 だ と いう のに   なに よ   この 寒気 ｡｡｡',
#  'おばけ とか   いる わけ ない しっ !',
#  '何 より も   科学 的 じ ゃないっっ !',
#  '白い 服   ずぶ ぬれ の 髪',
#  '笑っ てる   あの 人 は   誰 な の !?',
#  '臨 ・ 兵 ・ 闘 ・ 者 ・ 皆 ・ 陣 ・ 列 ・ 在 ・ 前',
#  'って ぜんぜん   効か ない じゃん !!',
#  'お じゅず',
#  'だめ だ こりゃ',
#  '囲ま れ ちまっ た',
#  '戦う しか ない',
#  '',
#  'ワーオ   ワーオ   ワオ   ワーーオ',
#  'そ ー めん',
#  'ひやそ ー めん !',
#  'はい !',
#  'それ ! それ ! それ ! それ !',
#  'それ ! それ ! それ ! それ !',
#  '',
#  '幽霊 なんか   ぶっとばせ !!',
#  '延髄 蹴り で   けっとばせ !!',
#  '女の子 を   なめ ない で !!',
#  'ママ の 方 が   よっぽど 怖い わ',
#  'ゴースト なぞ   ぶっとばせ !!',
#  'せ いけん 突き で   ふっとば せ !!',
#  'ケンカ 上等   負け ない ぜ !!',
#  'たたる 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  'エビ 中   ゴーストバスターズ',
#  '',
#  'ゾンビ   ゾンビ   ゾンビ も き た ぞ !',
#  'に げろ   にげろ   追いつか れる ぞ !',
#  'やばい   やばい   噛み付か れる ぞ !',
#  'ぎゃ ーーーーー !',
#  '部活 の 帰り   真っ暗   8 時 過ぎ',
#  '近道   小道   抜け道   外人 基地',
#  '曇り空   急 に 雷',
#  '真っ 二つ   ケヤキ が 割れる',
#  'もぞもぞ と   ゾンビ が 動く',
#  '',
#  'あり え ない っ !!   夢 か 幻 だ わ ｡｡｡',
#  "Oh   my   God !   Why   don ' t   you   save   me   new ?",
#  'って 英語 通じ ます かぁ ?',
#  'ドロドロ',
#  'ぐちゃぐちゃ',
#  'だめ だ こりゃ',
#  '逃げ場 ふさが れ た',
#  'やっ ちゃ い ましょ う か',
#  'ワーオ   ワーオ   ワオ   ワーーオ',
#  'あー ぶら   かた ぶら   びばのんのん !!',
#  '',
#  'ゾンビ なんか   ぶっとばせ !!',
#  '飛び ひざ 蹴り で   けっとばせ !!',
#  'ニッポン 女子   なめ ない で !!',
#  '先生 の 方 が   よっぽど 怖い わ',
#  'アン   ドュー   トロ ワ ☆   で   ぶっとばせ !!',
#  'ラリアット で   ふっとば せ !!',
#  '百戦錬磨   負け ない ぜ !!',
#  '襲う 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  '今夜 は スリラー   スリラー ナイト',
#  'アーメン',
#  'そ ー めん',
#  'ひやそ ー めん !',
#  'はい !',
#  'それ ! それ ! それ ! それ !',
#  'それ ! それ ! それ ! それ !',
#  '幽霊 なんか   ぶっとばせ !!',
#  '延髄 蹴り で   けっとばせ !!',
#  '女の子 を   なめ ない で !!',
#  'パパ の 方 が   ある 意味 怖い わ',
#  'ゴースト なぞ   ぶっとばせ !!',
#  'せ いけん 突き で   ふっとば せ !!',
#  'ケンカ 上等   負け ない ぜ !!',
#  'たたる 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  'エビ 中   ゴーストバスターズ',
#  'いつか 語り合っ た 想い を 抱え',
#  '約束 の 場所 たどり着く まで',
#  '強がる ほど に 涙 は 溢れ',
#  '永遠 じゃ ない 今 が 始まる',
#  '止まら ない で 胸 の 奥',
#  'しまい こん だ 色とりどり の 光',
#  '忘れ ない よう に 進め ば いい',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  '笑え ない 日 だって ある けど',
#  '君 の 全て が 明日 を てらす から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  '抱え きれ ない ほど の 願い事',
#  '全て が 叶わ ない の 分かっ てる',
#  'それでも 手 を 引い て くれる 君 が いる から',
#  'また 歩き 出せる よ',
#  'いつも どおり に',
#  '笑い あっ た いくつ も の',
#  '思い出 や 切ない 痛み も',
#  '忘れ ない よ この 空 に 色 を 添え て',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  'こぼれ そう な 涙 拭う 手',
#  '君 の ぬくもり',
#  'すべて 知っ てる から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  '曖昧 な 日々 を 繋い でる',
#  '長く 続く 足跡',
#  'どこ まで 続く だろ う',
#  'どこ まで 行ける だろ う',
#  '確か な こと は 何 も ない けど',
#  '怖く ない',
#  '止まら ない で 胸 の 奥',
#  'しまい こん だ 色とりどり の 光',
#  '忘れ ない よう に 進め ば いい',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  '笑え ない 日 だって ある けど',
#  '君 の 全て が 明日 を てらす から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  'Say   Yeah   Say   Yeah',
#  'さあ 、 Say   Yeah   Say   Yeah',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '声 を 出し て よ',
#  'Hey ！ 加速 する DAYS 加熱 する BODY',
#  '私 の 愛 受け取れ ない ？   ( イイ ヨー ！ ！)',
#  '青二才 で も この 際',
#  '火遊び し て みる ？   By   my   side',
#  'Time   goes   by 磨け ば 輝く っし ょいけるっしょ ！',
#  'そんな エモ め の 土曜 も Change   up',
#  'ちょっと サビ まで stay   up',
#  '大器晩成 さ',
#  'これから もっと 輝い て ゆく の',
#  '愛 と 正義 さ',
#  'ブチ か ます から つい て き て',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ さあ   SHAKE ！   SHAKE ！',
#  'ハイ ！ 格好 の STUDY 思考 の SWAY',
#  '楽しく ない なら 用 は ない',
#  '本日 は 膝 上 20 cm (！？)',
#  'でも 無敵 の 私 は 怯ま ない',
#  '髪 も バッチリ でも 少し Chilly',
#  '何 も 知ら ない から 終われ ない',
#  '純情 ・ 友情 ・ バカ 参上 ( ハァーイ ！！)',
#  'まだ 知ら ない 天井',
#  '絶体絶命 の',
#  '状況 も もっと 楽しん で ゆく の さ',
#  '笑止千万 さ',
#  'かっ飛ばす から つい て き て',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ 今   SHAKE ！   SHAKE ！',
#  'HEY ,   GUYS ！   BOYS   AND   GIRLS',
#  '今 から 言う こと よく 聞き な',
#  '命 の 限り 手 挙げろ',
#  'つい て こ れる やつ は つい て 来い',
#  '私 たち の 姿 よく 見 とけ',
#  '半端 な やつ は 今 帰り な',
#  'さあ 、 いけん の か ？ やれん の か ？',
#  '分かっ た やつ は 返事 しろ',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ ほら ！   SHAKE ！   SHAKE ！',
#  '',
#  '放課後   ど しゃぶり の 雨 の 中 で',
#  '傘 も ささ ず 立ちすくむ',
#  '彼女 と 彼 が 付き合っ てる こと',
#  '初めて 聞い て しまっ た',
#  '',
#  '入学 式 から 今日 まで ずっと',
#  '隠し て い た この 気持ち',
#  '',
#  '誰 に も ゆずる わけ に いか ない と',
#  '心 に 決め て た のに',
#  '',
#  '｢ 彼 の こと が 好き   応援 し て よ ね !!｣',
#  '( セリフ )',
#  '｢ 彼 の こと が 好き な ん だ   応援 し て くれる よ ね ?｣',
#  '突然   打ち明け られ た あの 日',
#  '友情   愛情   選ぶ こと 出来 なく て',
#  '作り笑い',
#  'し て い た   REGRET !!',
#  '',
#  '泣け ど 叫べ ど   戻せ ない   Destiny',
#  'こんなに   好き な のに   想い は 届か ない',
#  '流す 涙 が   雨 に 消え て いく',
#  '二 人 の 幸せ を   永遠 に 祈る よ',
#  "I   Love   you   でも   It ' s   Too   Late",
#  '嗚呼   ど しゃぶり リグレット',
#  '',
#  '放課後   ど しゃぶり の 雨 の 中 で',
#  '肩 寄せ あい 歩い てる',
#  '周り も 見え ない   二 人 の 世界',
#  '憧れ の 相合傘',
#  '',
#  'ふざけ て じゃれ あう   彼 と 彼女 の',
#  '見 た こと ない その 笑顔',
#  '',
#  'ほんと なら 私 が すぐ 隣 で',
#  '笑っ て た はず な のに',
#  '',
#  '｢ 私 も 好き な の   負け ない ん だ から !!｣',
#  '( セリフ )',
#  '｢ 私 も 好き な の ! 負け ない ん だ から !!｣',
#  '素直 に 言え たら よかっ た のに',
#  '勇気 が 足り ず に 気持ち ごまかし て たら',
#  '愛情 も',
#  'なくし た   REGRET !!',
#  '',
#  '寝 て も 覚め て も   止まら ない 涙',
#  '神様   教え て よ   夢 は 叶わ ない の ?',
#  'もしも 時間 を   戻せる の なら ば',
#  'あなた へ この 想い   全身 で 届けよ う',
#  "I   Love   You ・ ・ ・   You   Don ' t   Love   Me .",
#  '嗚呼   ど しゃぶり リグレット',
#  '初めて いだい た 恋心',
#  '忘れ られる わけ が ない じゃ ない',
#  'この 胸 の 痛み 思い出 に   変わる の か な',
#  '嗚呼   雨 が やま ない よ',
#  '',
#  '泣け ど 叫べ ど 戻せ ない   Destiny',
#  'こんなに 好き な のに   想い は 届か ない',
#  '',
#  '流す 涙 が   雨 に 消え て いく',
#  '二 人 の 幸せ を   永遠 に 祈る よ',
#  "I   Love   You   でも   It ' s   Too   Late",
#  '嗚呼   ど しゃぶり リグレット',
#  'ドン どど ・ どん どど ・ ドーン っ ！',
#  '打ち上げろ 花火',
#  '寝 て も 覚め て も',
#  '終わら ない ジャンボリー',
#  'なぜ そこ まで と わけ わから ん ほど の 汗 と 努力 で',
#  '掘り出し物 の 夢 を 磨き 上げ ここ まで き た',
#  'ちょっと 待っ て あっ ため た',
#  'ヴォンゴレー ！ 食べる から',
#  '銀河系 中 同時 進行 頭上 げろ ！',
#  '土星 の 輪っか な 街 で 君 と スウィーテスト な 多忙',
#  'ここ で 会っ た が 百 年 目 ね 組ん ず 解れ つ',
#  '25 . 6 時間 じゃ 足り ない',
#  '水金 地 火 木 な エヴリデイ',
#  '君 と 出会え た 奇跡 に',
#  'ナ・ナ・ナ・ナ・ナ・ナ・ナ・ナ・ナマステ ！ ナマ ステ ！',
#  'ワオ ！',
#  'ダイヤモンド が 眠る 国 が ある 行っ て み たい な',
#  'オイミヤコン 村 は 、 マイナス 71 度 めっちゃ 寒い ！',
#  'テン ガロン で バンガロー に',
#  'ボンソワール ！ 叶う まで',
#  '頑張ろ う ぜ 皆 、 バンジョー ！ かき鳴らし て ！',
#  'トロピカル な 水着 で   Yes ！ ！ 君 と スウィーテスト な 多忙',
#  'ナビ も つけ ず に 回り道 で 全部 想い出',
#  '土星 の 輪っか な 街 で 君 と スウィーテスト な 多忙',
#  '月 の 光 に 溶け た ぼく ら 歌う 都々逸 ！',
#  '音楽 室 の 壁 に 飾ら れ た 肖像 画',
#  '一 人 だけ 校長 先生 に',
#  '似 てる の が ド・ド・ド・ド・ドビュッシー ！ ドビュッシー ！',
#  'ワオ ！',
#  'ドン どど ・ どん どど ・ ドーン っ ！',
#  '打ち上げろ 花火',
#  '寝 て も 覚め て も',
#  '終わら ない ジャンボリー',
#  'ゴー ！ Ready ゴー ！ Ready ゴー っ ！',
#  '共に 行こ う ！ 未だ 見 ぬ 世界 へ ！',
#  'ゴー ！ Ready ゴー ！ Ready ゴー っ ！',
#  'いざ 、 君 と',
#  'スウィーテスト・ 多忙 な デイズ ！',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '恵比寿 駅 発 の 土星 行き',
#  '加速度 ぐんぐん 上げ ましょ う',
#  'テスト の 範囲 は 小宇宙',
#  '居残り 確定 明日 の 授業',
#  'ゆらゆら ゆらゆら 流れ着き',
#  '今日 も 宿題 は 後回し',
#  '水金 地 火 木 土 天海 ( 冥 )',
#  '放課後 カラオケ よそ の 惑星',
#  'あぁ 麗し の ブラウニー',
#  '( ひとつ ふたつ もう 止まら ない )',
#  'あれれ ？ ちょっと もしか し たら',
#  'カロリー オーバー じゃん ？ ！',
#  '( 甘い もの なら 別 次元 )',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '地球 は どうやら 忙しい',
#  'ハイファイワイファイ もう いっぱい',
#  '明治 大正 昭和 平成',
#  '文明開化 の 音 が する',
#  'あぁ 追憶 の フィナンシェ',
#  '( もっと キミ の 声 聞か せ て よ )',
#  'ちょっと ！ すぐ に 交信 する の やめ て よ 火星 人',
#  '( ぴぴぴぴぴぴぴぴぴぴぴぴ )',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '夜 の クラブ ビジョン 潜め た   Rainbow   Gray に',
#  '遠ざかる デジャブ と 近づく 夏 の 鼓動',
#  'もう 切ない ほど 燃え だそ う と し てる の',
#  'いつか ら か 時めい て 何気ない 日常 まで',
#  'シングル TONE で お願い 「 好き 」 の 響き が 聞き たく て',
#  'ノイズ さえ も ハモ り だす 予感 が する の よ',
#  'シングル TONE で お願い 過去 も これから も 刻み だす',
#  '雨 音 に まどろん で 二 人 の 未来 回り だす',
#  'ふい に すれ違っ た 心 の 行方 さえ',
#  'その 素振り 隠し て あなた は 目 を そらす',
#  'ほら いつのまにか 二 人 を 繋げ て く',
#  '当たり前 に 流れ て く 何気ない 日常 から',
#  'シングル TONE で お願い 儚く 砕け そう な ハーモナイズ',
#  'あなた と は 突き抜ける 予感 が する の よ',
#  'シングル TONE で お願い 胸 の 隙間 から 弾け 飛ぶ',
#  'いつか ら か 時 を 超え て 二 人 は 未来 作りだそ う',
#  '大好き な 理由 を 簡単 な 言葉 で 伝え たい',
#  'そう 私 を 信じよ う',
#  'シングル TONE で お願い 「 好き 」 の 響き が 聞き たく て',
#  'ノイズ さえ も ハモ り だす 予感 が する の よ',
#  'シングル TONE で お願い 過去 も これから も 刻み だす',
#  '雨 音 に まどろん で 二 人 の 未来 回り だす',
#  'なんて 切ない ん だろ う 時間 が 出し た 答え が 胸 を 締め付ける',
#  'おはよう の 声 と 頭 に ポ ン と 置か れ た 手 は 大人 の 香り が し てる 気 が し た',
#  '教室 の 窓 いつも 見 て た あなた は きっと 今 も 気づい て ない よ',
#  'さようなら 春 が 近づい て あなた に 会え なく なる ん だ ね',
#  '伝え たい この 気持ち だけ が ずっと 言え ない まま でし た',
#  '本当は すごく 寂しい ん だ よ ほら ね すぐ に 涙 が 溢れ た',
#  'なんて 切ない ん だろ う 当たり前 の 毎日 が 変わっ ちゃう みたい だ',
#  '放課後 の 度 に 探し まわっ た 廊下 は もう 思い出 の 色 に 深く 染まっ た',
#  '二 人 で 歩く 時間 も 無くなる 事 想像 すら も し て い なかっ た',
#  'さようなら 叶わ ない 恋 と 知っ て も 想い 続け てる',
#  '伝え たい この 気持ち だけ は 最後 まで 言え ない まま で いい',
#  'あの 笑顔 思い出す 度 に 胸 の 奥 が チクリ と 疼い た',
#  '優しい 記憶 消え ない よう に',
#  '哀しみ だけ を ぎゅっと 胸 に 閉じ込め た なら',
#  '前 だけ を 向い て 行ける ？',
#  'さようなら いつか 話す よそ の 時 まで',
#  '帰り道 一 人 で そっと つぶやく 「 好き だ よ 。 きっと それでも 」',
#  'さようなら 春 が 近づい て あなた に 会え なく なる ん だ ね',
#  '伝え たい この 気持ち だけ が ずっと 言え ない まま でし た',
#  '本当は すごく 寂しい ん だ よ ほら ね すぐ に 涙 が 溢れ た',
#  'せめ ぎあうせめぎあう',
#  'ざわざわ',
#  'せめ ぎあうせめぎあう',
#  '心 が',
#  'せ ・ め ・ ぎ ・ あ ・ う',
#  '春休み モラトリアム 中学生',
#  'こ いっ ！ ！   こ いっ ！ ！   ゾッコン ！ ！',
#  'こ いっ ！ ！   こ いっ ！ ！   ロックオン ！ ！',
#  '心 の 筆箱 ガタガタ 落ち着か ない',
#  '授業 中 だって ギリギリ 見つめ てる',
#  'すれ違う 視線 希望 が 反比例',
#  '未だ 答え 「 Y ＝ X 」 の まま',
#  'この 気持ち まるで 素数 に ー さん ご ー な な ！ ！',
#  '絶対 に 割り切れ ない よ',
#  'え た にて ぃ ー',
#  '秘密 の 方程式',
#  '私 だけ に こっそり と 耳打ち し て',
#  '素っ気 ない 態度',
#  'そっぽ 向い ちゃっ て',
#  '好き の 裏返し ？ ！',
#  '超 前向き ！ ！',
#  '恋 の 面積 君 と 二 人 証明 し て み たい',
#  'せめ ぎあうせめぎあう',
#  'ぞくぞく',
#  'せめ ぎあうせめぎあう',
#  '妄想 ！ ！',
#  'せ ・ め ・ ぎ ・ あ ・ う',
#  'い て も たっ て も い られ ない',
#  'もどかしい 感情 × 100   ゾッコン ！ ！',
#  'みっともない ほど 君 に 夢中',
#  '宙ぶらりん の ハート どうし よう やる だけ やっ ちゃ え',
#  '伝え たい けど 伝え られ ない',
#  'もたもた し て たら 先 越さ れ ちゃう ソッコー ！ ！',
#  '嗚呼 、 悔しい けど ゾッコン な ん だ もん',
#  '桜 散っ てる 場合 じゃ ない から',
#  '春休み 直前',
#  'モラトリアムモラトリアムモラトリアム 中学生',
#  '放課後 ゲタ 箱 不意 に 君 が 現れ た',
#  '何 も 言え ない ちゃんと バイバイ し たかっ た',
#  'この 気持ち まるで 素数',
#  'に ー さん ご ー な な ！ ！',
#  '絶対 に 割り切れ ない よ',
#  'え た にて ぃ ー',
#  '新 学期 どぉ なっ ちゃう ん だろ',
#  '何 が なん でも 君 と 同じ クラス が いい',
#  '机 くっつけ て',
#  '教科書 忘れ た ぁ ～！！',
#  '面 と 向かっ て',
#  '集中 無 理っ ！ ！',
#  '居残り 授業 君 と 二 人 答え 合わせ を し たい',
#  'せめ ぎあうせめぎあう',
#  'ざわざわ',
#  'せめ ぎあうせめぎあう',
#  '葛藤 ！ ！',
#  'せ ・ め ・ ぎ ・ あ ・ う ・ せ ・ め ・ ぎ ・ あ ・ う',
#  'い て も たっ て も い られ ない',
#  'もどかしい 感情 × 100   ゾッコン ！ ！',
#  'みっともない ほど 君 に 夢中',
#  '宙ぶらりん の ハート どうし よう やる だけ やっ ちゃ え',
#  '伝え たい けど 伝え られ ない',
#  ...]

# %%
# !pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
from collections import Counter
import os
from argparse import Namespace


flags = Namespace(
    train_file='oliver.txt',
    seq_size=32,
    batch_size=16,
    embedding_size=64,
    lstm_size=64,
    gradients_norm=5,
    initial_words=['I', 'am'],
    predict_top_k=5,
    checkpoint_path='checkpoint',
)

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer()
def gen_wakati_txt(txt: str):
    return ' '.join(t.tokenize(txt, wakati=True))
df['wakati_line'] = df['line'].apply(gen_wakati_txt)
sentences = df['wakati_line'].tolist()
sentences
# Out:
# まっ た 事',
#  '返し て くれる なら',
#  '愛し て みせる のに',
#  '愛し て い たい の に 消え て なくなっ て しまう な',
#  'やめ られ ない よ',
#  '感情 的 に はなれ ない 君 は 僕 と 踊れ ば いい',
#  'ずっと 僕 と ！',
#  '愛し て い たい の に 消え て なくなっ て しまう な',
#  '手 に 負え ない ぜ',
#  '最終 的 に 笑え ない 君 も 僕 も 踊れ ば いい',
#  'ずっと 僕ら 踊れ ば いい',
#  'silver   body   to   ride',
#  'digital   rock   &   roll   tune',
#  'baby   baby   baby',
#  'you   are   new - animal',
#  'heavy   metalic',
#  'digital   summer   beach',
#  'baby   baby   baby',
#  "I   don ' t   know   everything !!   all !!",
#  'do   mo   a   ri   ga   to   baby',
#  'bo   ku   ra   no   se   i   shu   n',
#  'do   i   ta   shi   ma   shi   te   baby',
#  'bo   ku   ni   ma   ka   se   na   yo',
#  'super   psychic',
#  'sun   sun   sun   sun   sun   ...',
#  'baby   island',
#  'ge   -   ge   -   generation   X',
#  'do   mo   a   ri   ga   to   baby',
#  'bo   ku   ra   no   se   i   shu   n',
#  'do   i   ta   shi   ma   shi   te   baby',
#  'bo   ku   ni   ma   ka   se   na   yo',
#  'do   ko   ma   de   to   be   ru   ka',
#  'te   a   shi   wo   po   no   po   no',
#  'so   n   na   ko   n   na   " a   ri   ga   to "',
#  'ki   mi   wa   bo   ku   no   mo   no',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  '｢ 90 ｣｢ 91 ｣｢ 92 ｣｢ 93 ｣｢ 94 ｣｢ 95 ｣｢ 96 !!｣',
#  "bye   bye ('   o   '   )",
#  'チェケラッチョ',
#  'YO   DJ',
#  '何故か 鳴ん なかっ た アラーム',
#  '開か ず 踏切 閉まる ドア',
#  '何故か 上がん ない ウダツ',
#  '分かん ない 英文 ギブ し て 、 sleeping   sleeping',
#  '夢 の 中 なら ほら',
#  'かなり 無茶 め な シナリオ も',
#  'したい 放題 だっ た のに',
#  'ガ ツン おでこ に チョーク が 飛ん で き た',
#  '根拠 は 無い けど 大声 で 歌え ば 晴れる や',
#  'ただ で さえ 蒸し暑い 毎日',
#  'ハート ウォーミング は お呼び じゃ ない',
#  'いつの間にか やぶれ 捨て た 無 遅刻 無 欠席 スローガン',
#  'そん 代わり 大 親友   and   take   care   see   you   放課後 に また',
#  '居眠り ほっぺ の 跡 で トピック 話題 を さらお う',
#  '照り付ける 日差し 教室 は もう ちょっと で ブラジル',
#  'はじまり は ブラジル',
#  'おおかた ブラジル',
#  'YO   DJ',
#  '上書き さ れ て いく 最高 気温',
#  '反比例 下がる やる気 が どんどん',
#  'し た たた たる 汗 炭酸 飲み た ひ',
#  '干からび た ミミズ マジ に シンパシー',
#  'いち おく よん せん きゅう ひゃく メートル',
#  '太陽 発 校庭 経由 私',
#  '着 慣れ た 夏服 に ため息 ひとつ',
#  'A . S . A . P チャイム !',
#  '意味 なんて 無い けど それでも 今日 も 走る よ',
#  'ただ で さえ バテバテ の 季節 に',
#  'ハート ウォーミング は お呼び じゃ ない',
#  '下駄 箱 の 奥 の 方 に 忘れ て た 無 欠席 スローガン',
#  'そん 代わり 大 親友   and   take   care   see   you   放課後 に また',
#  '宿題 は ご飯 の 後 で メール 打ち ながら ゴロゴロ',
#  'とか 言い つつ も 明日 は プール アリ おおよそ ブラジル',
#  '三 段 重ね アイスクリーム',
#  '扇風機 に 向かっ て スクリーム ( A ” h ” h ” h ” h ” h ” )',
#  '蚊 に 刺さ れ て マジカチン',
#  '頭 突き の ひとつ でも か まし て やり たい',
#  'いつの間にか やぶれ 捨て た   無 遅刻 無 欠席 スローガン',
#  'そん 代わり   大 親友   and   take   care   see   you   放課後 に また',
#  '居眠り ほっぺ の 跡 で   トピック 話題 を さらお う',
#  '照り付ける 日差し   そこ どこ   ここ どこ   こりゃ ほぼ ブラジル',
#  'ほぼ ほぼ ブラジル',
#  'となり は コロンビア',
#  '君 と 僕 の あの 日々 が',
#  'いつも 強く つながっ てる よ',
#  'アイムサーチング   アイムサーチング',
#  'この 先 の 光 に   向かっ て ゆく なら',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '海底 に 潜む   シーラカンス',
#  'ゆっくり と 進化   照らし 出す',
#  '神 が いる として も   い ない として も',
#  '止め たく ない ん だ   僕ら の ストーリー',
#  'アイムサーチング   アイムサーチング',
#  '共に この 想い   あたため て ゆく から',
#  'PLAYBACK   PLAYBACK',
#  '願 わく ば   今 は そば に い て',
#  'PLAYBACK   PLAYBACK',
#  '生まれ変わっ て も   そう 君 の まま で い て',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '再生',
#  '感じとれる   この 先 の 光   見 に 行こ う',
#  'PLAYBACK   PLAYBACK',
#  '願 わく ば   今 は そば に い て',
#  'PLAYBACK   PLAYBACK',
#  '大人 に なっ て も   そう 君 の まま で い て',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  'Uuu',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  '新しい 季節 巡り',
#  '揺るぎない この 想い',
#  '窓 を 開け たら すぐ に',
#  '君 の もと へ 飛び込む よ',
#  '始めよ う 今 この 場所 で',
#  'メラメラ 燃やす 想い',
#  'はち切れ そう な 憂鬱 に',
#  'ハッピー な クラッカー 打ち込ん で',
#  'ねぇ 言葉 じゃ 照れ ちゃう よ',
#  'ごまかし ちゃい そう で',
#  'ねぇ その 手 を 握り',
#  'ステージ に 立っ て 奏でよ う',
#  'あぁ 今 は この リズム に 乗っ て',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '数え て み ましょ 羊 さん',
#  'あっち の 夢 は 見る けど',
#  'こっち の 夢 を 叶える の',
#  '今 すぐ 全 速 前進 で',
#  'ねぇ 涙 が 溢れ て',
#  '濡らし た あの 日',
#  'ねぇ 宝物 に なっ て',
#  'この 背中 を 押し て くれる',
#  'あぁ 今 も この リズム に ノ って',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '「 私 もう 迷わ ない ！   みんな ー いく よっ ！ 」',
#  'Kick   and   punch   で   We   win ！',
#  'Chop   and   stick   で   Eat   in ！',
#  'Kick   for   kick   は   Win - win ！',
#  'チャンス は どこ ？   Checking ！',
#  '見つけ て   Getting ！',
#  'Big   wave 到来   Swimming ！',
#  'あぁ あの 頃 の 私 たち は きっと',
#  '大切 な 事 を 見失っ て い た ね',
#  'あぁ これから は 誰 に も 負け ない よ',
#  'あなた が くれ た 魔法',
#  '光 の 挿す 方 へ と',
#  'あぁ 今 は この リズム に 乗っ て',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら   ほら   hot   up ！ ！ ！',
#  'さあ さ みんな よっ て らっしゃい 小麦 ふっ て パン パンパン',
#  '揚げる ん だ エビ フライ どんと 行っ ちゃっ て',
#  'エビ に 恋せよ 乙女 でっかい でっかい の 大好き',
#  '洋食 の 王様 だ ワオ !',
#  '( サクサク 揚げろ 揚げろ 揚げろ )',
#  'ゴクリ 舌なめずり ( ゴクリ )',
#  'みんな テンション 上げ 上げ ( 上げ 上げ )',
#  'パーティー ムード なんか いい ぞ !',
#  'それ っ い !',
#  '( え ～ じゃ ない ええ じゃ ない じゃ ない )',
#  'ロブスターオマールエビ 浮気 し ちゃい そう',
#  'でも 君 に 一途 だ よ',
#  'サクサクプリプリプリ',
#  'パリパリカリカリカリ',
#  'なんて なんて 美味しい の 早く 早く フライ !',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'エビ フライ 揚げろ 揚げ 揚げ ジュワジュワジュワ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと テンション',
#  'グイグイグイ 上げ て',
#  '挙げ 挙げ 挙げ 挙げ 挙げ 挙げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケングー !( あいこ ～!)',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  'オードブル で 主役 フライ 級 の チャンピオン',
#  '学園中 人気 沸騰 ワオ !',
#  '( テンション 上がる 上がる 上がる )',
#  '熱い 油 の 中 ( あ ち ゅい )',
#  'なんて 君 は たくましい ( たくましい )',
#  '愛し てる でも 食べ ちゃう ぞ !',
#  '( え ～ じゃ ない ええ じゃ ない じゃ ない )',
#  '焼い ちゃ ダメ 煮 て も ダメ もっと 美味しく し て',
#  'こんがり と キツネ 色',
#  'サクサクプリプリプリ',
#  'パリパリカリカリカリ',
#  'サクサクプリプリプリエビエビエビフライ',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  'エビ フライ 高く 高く 高く フライフライフライ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと もっと',
#  'サクサク サク 揚げ て',
#  '挙げ 挙げ 挙げ 挙げ 挙げ 挙げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケンチョキ !( 負け た !)',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  '大好き ～ ジュワ ～ 美味しい ～',
#  '揚げ て 上げ て 揚げ て 上げ て',
#  '揚げ て 上げ て 揚げ て 上げ て',
#  '真っ黒 け っけ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'エビ フライ 揚げろ 揚げ 揚げ ジュワジュワジュワ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと テンション',
#  'グイグイグイ 上げ て',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケン パー !( 勝っ た ～!)',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  'さあ さ みんな よっ て らっしゃい 小麦 ふっ て パン パンパン',
#  '揚げる ん だ エビ フライ 全部 食べ ちゃっ て !( ジュワ ～)',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'お ばあちゃん だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  '高校生 だって 中学生',
#  'いつ でも   ( いつも )   こうして   ( みんな )',
#  'バカ みたい に 遊ん で たい な',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'ヲタ さん だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'スタッフ さん も 中学生',
#  'ずーっと ね   ( ずーっと )   みんな と   ( ここ で )',
#  '今 の まんま 笑お う ね !',
#  'ほら 聞こえ て き まし た 下校 の ベル です',
#  '本日 これ にて おしまい',
#  '忘れ物 せ ず に 帰り ましょ',
#  '少し さみしい な 下校 の ベル です',
#  'また 次回 お 逢い し ましょ う',
#  '恵比寿 中学 で 永遠 に 中学生 !',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'いくつ だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  '気分 次第 中学生',
#  'どんなに   ( いつか )   大きく   ( なっ て も )',
#  'この 気持ち 忘れ ない',
#  'せ ー の',
#  'キンコンカンコンキンコンカンコン 下校 の ベル です',
#  '初心 忘れる べから ず',
#  '全然 エラく も ない です が',
#  'おわり の おしらせ 下校 の ベル です',
#  '次 の 登校 日 い つ でしょ ね',
#  'ホームページ チェック し て ね 永遠 に 中学生 !',
#  '今日 は 来 て くれ て ほんとに ありがとう !',
#  'ありがと !',
#  '聞こえ て き まし た 下校 の ベル です',
#  '本日 これ にて おしまい',
#  '忘れ物 せ ず に 帰り ましょ',
#  '少し さみしい な 下校 の ベル です',
#  'また 次回 お 逢い し ましょ う',
#  '恵比寿 中学 で 永遠 に 中学生 !',
#  '「 歯磨 け よー 」 「 宿題 しろ よー 」 「 気 を つけ て 帰れ よー 」',
#  '「 いい 夢みろ よー 」 「 お 父 さ ー ん 」',
#  '「 他 の 現場 も 行け よー 」 「 風邪 ひく な よー 」 「 チョット だけ よー 」',
#  '「 ファイト いっ ぱ ー つ 」 「 物販 も よろしく ー 」',
#  '永遠 に 中学生 !',
#  '「 みなさま ごきげんよう !!」',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  'ねぇ さっき 全然 興味 が ない って 言っ て た のに',
#  'どうして み て ん の ?   周辺 視覚 で',
#  'セクシー 仙人',
#  'カンフー 万 人',
#  '今 は もはや パンダ な 気分 ( き もち ) の 三 人',
#  'そんな まさか',
#  'Holiday',
#  'ちく わ ぶ くわえ ながら 柔軟 体操',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  '友人 と ベンチ',
#  '最高 の ランチ',
#  '最初 の 3 年 の 記憶 は 白紙',
#  '気さく に JUMP !!',
#  '町 へ 続く 道 と 逆 の 道',
#  '身振り 手振り で 渡れる 世界',
#  'オーロラ',
#  'かまぼこ の 味 が する アジア の グルメ',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  '君 が 桟橋 の 向こう 側 から',
#  '一所懸命 手 を 振る 姿 が',
#  '背後 の 背景 に なじみ',
#  '僕 は いつのまにか 空 を かじり',
#  '枯れ は の 日々 を くぐり抜け て',
#  '気まぐれ Rally - Ho',
#  '君 が 桟橋 の 向こう 側 から',
#  '一所懸命 手 を 振る 姿 が',
#  '背後 の 背景 に なじみ',
#  '僕 は いつのまにか 空 を かじり',
#  '枯れ は の 日々 を くぐり抜け て',
#  '気まぐれ Rally - Ho',
#  'ちゃんばら おやじ と お ばあちゃん',
#  '頭 から 血 流し てる こりゃ いかん',
#  'チンピラ イライラ   疎外 感',
#  'お 肌 つるつる する の か な ? 白湯',
#  'メロス の 泉 を 探し て',
#  '北 、 南 、 東 、 西   羽ばたい て',
#  'たま に は 大胆 か まし て   いま',
#  '突撃 いたし ます る よ',
#  '突撃 いたし ます る よ',
#  '突撃 いたし ます る よ',
#  '',
#  'おばけ   おばけ   おばけ が くる ぞ !',
#  'に げろ   にげろ   追いつか れる ぞ !',
#  'やばい   やばい   取り 憑かれる ぞ !',
#  'ぎゃ ーーーーー !',
#  '真夜中   真夏 に   マジ でき も だ めし',
#  '夏 だ と いう のに   なに よ   この 寒気 ｡｡｡',
#  'おばけ とか   いる わけ ない しっ !',
#  '何 より も   科学 的 じ ゃないっっ !',
#  '白い 服   ずぶ ぬれ の 髪',
#  '笑っ てる   あの 人 は   誰 な の !?',
#  '臨 ・ 兵 ・ 闘 ・ 者 ・ 皆 ・ 陣 ・ 列 ・ 在 ・ 前',
#  'って ぜんぜん   効か ない じゃん !!',
#  'お じゅず',
#  'だめ だ こりゃ',
#  '囲ま れ ちまっ た',
#  '戦う しか ない',
#  '',
#  'ワーオ   ワーオ   ワオ   ワーーオ',
#  'そ ー めん',
#  'ひやそ ー めん !',
#  'はい !',
#  'それ ! それ ! それ ! それ !',
#  'それ ! それ ! それ ! それ !',
#  '',
#  '幽霊 なんか   ぶっとばせ !!',
#  '延髄 蹴り で   けっとばせ !!',
#  '女の子 を   なめ ない で !!',
#  'ママ の 方 が   よっぽど 怖い わ',
#  'ゴースト なぞ   ぶっとばせ !!',
#  'せ いけん 突き で   ふっとば せ !!',
#  'ケンカ 上等   負け ない ぜ !!',
#  'たたる 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  'エビ 中   ゴーストバスターズ',
#  '',
#  'ゾンビ   ゾンビ   ゾンビ も き た ぞ !',
#  'に げろ   にげろ   追いつか れる ぞ !',
#  'やばい   やばい   噛み付か れる ぞ !',
#  'ぎゃ ーーーーー !',
#  '部活 の 帰り   真っ暗   8 時 過ぎ',
#  '近道   小道   抜け道   外人 基地',
#  '曇り空   急 に 雷',
#  '真っ 二つ   ケヤキ が 割れる',
#  'もぞもぞ と   ゾンビ が 動く',
#  '',
#  'あり え ない っ !!   夢 か 幻 だ わ ｡｡｡',
#  "Oh   my   God !   Why   don ' t   you   save   me   new ?",
#  'って 英語 通じ ます かぁ ?',
#  'ドロドロ',
#  'ぐちゃぐちゃ',
#  'だめ だ こりゃ',
#  '逃げ場 ふさが れ た',
#  'やっ ちゃ い ましょ う か',
#  'ワーオ   ワーオ   ワオ   ワーーオ',
#  'あー ぶら   かた ぶら   びばのんのん !!',
#  '',
#  'ゾンビ なんか   ぶっとばせ !!',
#  '飛び ひざ 蹴り で   けっとばせ !!',
#  'ニッポン 女子   なめ ない で !!',
#  '先生 の 方 が   よっぽど 怖い わ',
#  'アン   ドュー   トロ ワ ☆   で   ぶっとばせ !!',
#  'ラリアット で   ふっとば せ !!',
#  '百戦錬磨   負け ない ぜ !!',
#  '襲う 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  '今夜 は スリラー   スリラー ナイト',
#  'アーメン',
#  'そ ー めん',
#  'ひやそ ー めん !',
#  'はい !',
#  'それ ! それ ! それ ! それ !',
#  'それ ! それ ! それ ! それ !',
#  '幽霊 なんか   ぶっとばせ !!',
#  '延髄 蹴り で   けっとばせ !!',
#  '女の子 を   なめ ない で !!',
#  'パパ の 方 が   ある 意味 怖い わ',
#  'ゴースト なぞ   ぶっとばせ !!',
#  'せ いけん 突き で   ふっとば せ !!',
#  'ケンカ 上等   負け ない ぜ !!',
#  'たたる 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  'エビ 中   ゴーストバスターズ',
#  'いつか 語り合っ た 想い を 抱え',
#  '約束 の 場所 たどり着く まで',
#  '強がる ほど に 涙 は 溢れ',
#  '永遠 じゃ ない 今 が 始まる',
#  '止まら ない で 胸 の 奥',
#  'しまい こん だ 色とりどり の 光',
#  '忘れ ない よう に 進め ば いい',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  '笑え ない 日 だって ある けど',
#  '君 の 全て が 明日 を てらす から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  '抱え きれ ない ほど の 願い事',
#  '全て が 叶わ ない の 分かっ てる',
#  'それでも 手 を 引い て くれる 君 が いる から',
#  'また 歩き 出せる よ',
#  'いつも どおり に',
#  '笑い あっ た いくつ も の',
#  '思い出 や 切ない 痛み も',
#  '忘れ ない よ この 空 に 色 を 添え て',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  'こぼれ そう な 涙 拭う 手',
#  '君 の ぬくもり',
#  'すべて 知っ てる から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  '曖昧 な 日々 を 繋い でる',
#  '長く 続く 足跡',
#  'どこ まで 続く だろ う',
#  'どこ まで 行ける だろ う',
#  '確か な こと は 何 も ない けど',
#  '怖く ない',
#  '止まら ない で 胸 の 奥',
#  'しまい こん だ 色とりどり の 光',
#  '忘れ ない よう に 進め ば いい',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  '笑え ない 日 だって ある けど',
#  '君 の 全て が 明日 を てらす から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  'Say   Yeah   Say   Yeah',
#  'さあ 、 Say   Yeah   Say   Yeah',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '声 を 出し て よ',
#  'Hey ！ 加速 する DAYS 加熱 する BODY',
#  '私 の 愛 受け取れ ない ？   ( イイ ヨー ！ ！)',
#  '青二才 で も この 際',
#  '火遊び し て みる ？   By   my   side',
#  'Time   goes   by 磨け ば 輝く っし ょいけるっしょ ！',
#  'そんな エモ め の 土曜 も Change   up',
#  'ちょっと サビ まで stay   up',
#  '大器晩成 さ',
#  'これから もっと 輝い て ゆく の',
#  '愛 と 正義 さ',
#  'ブチ か ます から つい て き て',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ さあ   SHAKE ！   SHAKE ！',
#  'ハイ ！ 格好 の STUDY 思考 の SWAY',
#  '楽しく ない なら 用 は ない',
#  '本日 は 膝 上 20 cm (！？)',
#  'でも 無敵 の 私 は 怯ま ない',
#  '髪 も バッチリ でも 少し Chilly',
#  '何 も 知ら ない から 終われ ない',
#  '純情 ・ 友情 ・ バカ 参上 ( ハァーイ ！！)',
#  'まだ 知ら ない 天井',
#  '絶体絶命 の',
#  '状況 も もっと 楽しん で ゆく の さ',
#  '笑止千万 さ',
#  'かっ飛ばす から つい て き て',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ 今   SHAKE ！   SHAKE ！',
#  'HEY ,   GUYS ！   BOYS   AND   GIRLS',
#  '今 から 言う こと よく 聞き な',
#  '命 の 限り 手 挙げろ',
#  'つい て こ れる やつ は つい て 来い',
#  '私 たち の 姿 よく 見 とけ',
#  '半端 な やつ は 今 帰り な',
#  'さあ 、 いけん の か ？ やれん の か ？',
#  '分かっ た やつ は 返事 しろ',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ ほら ！   SHAKE ！   SHAKE ！',
#  '',
#  '放課後   ど しゃぶり の 雨 の 中 で',
#  '傘 も ささ ず 立ちすくむ',
#  '彼女 と 彼 が 付き合っ てる こと',
#  '初めて 聞い て しまっ た',
#  '',
#  '入学 式 から 今日 まで ずっと',
#  '隠し て い た この 気持ち',
#  '',
#  '誰 に も ゆずる わけ に いか ない と',
#  '心 に 決め て た のに',
#  '',
#  '｢ 彼 の こと が 好き   応援 し て よ ね !!｣',
#  '( セリフ )',
#  '｢ 彼 の こと が 好き な ん だ   応援 し て くれる よ ね ?｣',
#  '突然   打ち明け られ た あの 日',
#  '友情   愛情   選ぶ こと 出来 なく て',
#  '作り笑い',
#  'し て い た   REGRET !!',
#  '',
#  '泣け ど 叫べ ど   戻せ ない   Destiny',
#  'こんなに   好き な のに   想い は 届か ない',
#  '流す 涙 が   雨 に 消え て いく',
#  '二 人 の 幸せ を   永遠 に 祈る よ',
#  "I   Love   you   でも   It ' s   Too   Late",
#  '嗚呼   ど しゃぶり リグレット',
#  '',
#  '放課後   ど しゃぶり の 雨 の 中 で',
#  '肩 寄せ あい 歩い てる',
#  '周り も 見え ない   二 人 の 世界',
#  '憧れ の 相合傘',
#  '',
#  'ふざけ て じゃれ あう   彼 と 彼女 の',
#  '見 た こと ない その 笑顔',
#  '',
#  'ほんと なら 私 が すぐ 隣 で',
#  '笑っ て た はず な のに',
#  '',
#  '｢ 私 も 好き な の   負け ない ん だ から !!｣',
#  '( セリフ )',
#  '｢ 私 も 好き な の ! 負け ない ん だ から !!｣',
#  '素直 に 言え たら よかっ た のに',
#  '勇気 が 足り ず に 気持ち ごまかし て たら',
#  '愛情 も',
#  'なくし た   REGRET !!',
#  '',
#  '寝 て も 覚め て も   止まら ない 涙',
#  '神様   教え て よ   夢 は 叶わ ない の ?',
#  'もしも 時間 を   戻せる の なら ば',
#  'あなた へ この 想い   全身 で 届けよ う',
#  "I   Love   You ・ ・ ・   You   Don ' t   Love   Me .",
#  '嗚呼   ど しゃぶり リグレット',
#  '初めて いだい た 恋心',
#  '忘れ られる わけ が ない じゃ ない',
#  'この 胸 の 痛み 思い出 に   変わる の か な',
#  '嗚呼   雨 が やま ない よ',
#  '',
#  '泣け ど 叫べ ど 戻せ ない   Destiny',
#  'こんなに 好き な のに   想い は 届か ない',
#  '',
#  '流す 涙 が   雨 に 消え て いく',
#  '二 人 の 幸せ を   永遠 に 祈る よ',
#  "I   Love   You   でも   It ' s   Too   Late",
#  '嗚呼   ど しゃぶり リグレット',
#  'ドン どど ・ どん どど ・ ドーン っ ！',
#  '打ち上げろ 花火',
#  '寝 て も 覚め て も',
#  '終わら ない ジャンボリー',
#  'なぜ そこ まで と わけ わから ん ほど の 汗 と 努力 で',
#  '掘り出し物 の 夢 を 磨き 上げ ここ まで き た',
#  'ちょっと 待っ て あっ ため た',
#  'ヴォンゴレー ！ 食べる から',
#  '銀河系 中 同時 進行 頭上 げろ ！',
#  '土星 の 輪っか な 街 で 君 と スウィーテスト な 多忙',
#  'ここ で 会っ た が 百 年 目 ね 組ん ず 解れ つ',
#  '25 . 6 時間 じゃ 足り ない',
#  '水金 地 火 木 な エヴリデイ',
#  '君 と 出会え た 奇跡 に',
#  'ナ・ナ・ナ・ナ・ナ・ナ・ナ・ナ・ナマステ ！ ナマ ステ ！',
#  'ワオ ！',
#  'ダイヤモンド が 眠る 国 が ある 行っ て み たい な',
#  'オイミヤコン 村 は 、 マイナス 71 度 めっちゃ 寒い ！',
#  'テン ガロン で バンガロー に',
#  'ボンソワール ！ 叶う まで',
#  '頑張ろ う ぜ 皆 、 バンジョー ！ かき鳴らし て ！',
#  'トロピカル な 水着 で   Yes ！ ！ 君 と スウィーテスト な 多忙',
#  'ナビ も つけ ず に 回り道 で 全部 想い出',
#  '土星 の 輪っか な 街 で 君 と スウィーテスト な 多忙',
#  '月 の 光 に 溶け た ぼく ら 歌う 都々逸 ！',
#  '音楽 室 の 壁 に 飾ら れ た 肖像 画',
#  '一 人 だけ 校長 先生 に',
#  '似 てる の が ド・ド・ド・ド・ドビュッシー ！ ドビュッシー ！',
#  'ワオ ！',
#  'ドン どど ・ どん どど ・ ドーン っ ！',
#  '打ち上げろ 花火',
#  '寝 て も 覚め て も',
#  '終わら ない ジャンボリー',
#  'ゴー ！ Ready ゴー ！ Ready ゴー っ ！',
#  '共に 行こ う ！ 未だ 見 ぬ 世界 へ ！',
#  'ゴー ！ Ready ゴー ！ Ready ゴー っ ！',
#  'いざ 、 君 と',
#  'スウィーテスト・ 多忙 な デイズ ！',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '恵比寿 駅 発 の 土星 行き',
#  '加速度 ぐんぐん 上げ ましょ う',
#  'テスト の 範囲 は 小宇宙',
#  '居残り 確定 明日 の 授業',
#  'ゆらゆら ゆらゆら 流れ着き',
#  '今日 も 宿題 は 後回し',
#  '水金 地 火 木 土 天海 ( 冥 )',
#  '放課後 カラオケ よそ の 惑星',
#  'あぁ 麗し の ブラウニー',
#  '( ひとつ ふたつ もう 止まら ない )',
#  'あれれ ？ ちょっと もしか し たら',
#  'カロリー オーバー じゃん ？ ！',
#  '( 甘い もの なら 別 次元 )',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '地球 は どうやら 忙しい',
#  'ハイファイワイファイ もう いっぱい',
#  '明治 大正 昭和 平成',
#  '文明開化 の 音 が する',
#  'あぁ 追憶 の フィナンシェ',
#  '( もっと キミ の 声 聞か せ て よ )',
#  'ちょっと ！ すぐ に 交信 する の やめ て よ 火星 人',
#  '( ぴぴぴぴぴぴぴぴぴぴぴぴ )',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '夜 の クラブ ビジョン 潜め た   Rainbow   Gray に',
#  '遠ざかる デジャブ と 近づく 夏 の 鼓動',
#  'もう 切ない ほど 燃え だそ う と し てる の',
#  'いつか ら か 時めい て 何気ない 日常 まで',
#  'シングル TONE で お願い 「 好き 」 の 響き が 聞き たく て',
#  'ノイズ さえ も ハモ り だす 予感 が する の よ',
#  'シングル TONE で お願い 過去 も これから も 刻み だす',
#  '雨 音 に まどろん で 二 人 の 未来 回り だす',
#  'ふい に すれ違っ た 心 の 行方 さえ',
#  'その 素振り 隠し て あなた は 目 を そらす',
#  'ほら いつのまにか 二 人 を 繋げ て く',
#  '当たり前 に 流れ て く 何気ない 日常 から',
#  'シングル TONE で お願い 儚く 砕け そう な ハーモナイズ',
#  'あなた と は 突き抜ける 予感 が する の よ',
#  'シングル TONE で お願い 胸 の 隙間 から 弾け 飛ぶ',
#  'いつか ら か 時 を 超え て 二 人 は 未来 作りだそ う',
#  '大好き な 理由 を 簡単 な 言葉 で 伝え たい',
#  'そう 私 を 信じよ う',
#  'シングル TONE で お願い 「 好き 」 の 響き が 聞き たく て',
#  'ノイズ さえ も ハモ り だす 予感 が する の よ',
#  'シングル TONE で お願い 過去 も これから も 刻み だす',
#  '雨 音 に まどろん で 二 人 の 未来 回り だす',
#  'なんて 切ない ん だろ う 時間 が 出し た 答え が 胸 を 締め付ける',
#  'おはよう の 声 と 頭 に ポ ン と 置か れ た 手 は 大人 の 香り が し てる 気 が し た',
#  '教室 の 窓 いつも 見 て た あなた は きっと 今 も 気づい て ない よ',
#  'さようなら 春 が 近づい て あなた に 会え なく なる ん だ ね',
#  '伝え たい この 気持ち だけ が ずっと 言え ない まま でし た',
#  '本当は すごく 寂しい ん だ よ ほら ね すぐ に 涙 が 溢れ た',
#  'なんて 切ない ん だろ う 当たり前 の 毎日 が 変わっ ちゃう みたい だ',
#  '放課後 の 度 に 探し まわっ た 廊下 は もう 思い出 の 色 に 深く 染まっ た',
#  '二 人 で 歩く 時間 も 無くなる 事 想像 すら も し て い なかっ た',
#  'さようなら 叶わ ない 恋 と 知っ て も 想い 続け てる',
#  '伝え たい この 気持ち だけ は 最後 まで 言え ない まま で いい',
#  'あの 笑顔 思い出す 度 に 胸 の 奥 が チクリ と 疼い た',
#  '優しい 記憶 消え ない よう に',
#  '哀しみ だけ を ぎゅっと 胸 に 閉じ込め た なら',
#  '前 だけ を 向い て 行ける ？',
#  'さようなら いつか 話す よそ の 時 まで',
#  '帰り道 一 人 で そっと つぶやく 「 好き だ よ 。 きっと それでも 」',
#  'さようなら 春 が 近づい て あなた に 会え なく なる ん だ ね',
#  '伝え たい この 気持ち だけ が ずっと 言え ない まま でし た',
#  '本当は すごく 寂しい ん だ よ ほら ね すぐ に 涙 が 溢れ た',
#  'せめ ぎあうせめぎあう',
#  'ざわざわ',
#  'せめ ぎあうせめぎあう',
#  '心 が',
#  'せ ・ め ・ ぎ ・ あ ・ う',
#  '春休み モラトリアム 中学生',
#  'こ いっ ！ ！   こ いっ ！ ！   ゾッコン ！ ！',
#  'こ いっ ！ ！   こ いっ ！ ！   ロックオン ！ ！',
#  '心 の 筆箱 ガタガタ 落ち着か ない',
#  '授業 中 だって ギリギリ 見つめ てる',
#  'すれ違う 視線 希望 が 反比例',
#  '未だ 答え 「 Y ＝ X 」 の まま',
#  'この 気持ち まるで 素数 に ー さん ご ー な な ！ ！',
#  '絶対 に 割り切れ ない よ',
#  'え た にて ぃ ー',
#  '秘密 の 方程式',
#  '私 だけ に こっそり と 耳打ち し て',
#  '素っ気 ない 態度',
#  'そっぽ 向い ちゃっ て',
#  '好き の 裏返し ？ ！',
#  '超 前向き ！ ！',
#  '恋 の 面積 君 と 二 人 証明 し て み たい',
#  'せめ ぎあうせめぎあう',
#  'ぞくぞく',
#  'せめ ぎあうせめぎあう',
#  '妄想 ！ ！',
#  'せ ・ め ・ ぎ ・ あ ・ う',
#  'い て も たっ て も い られ ない',
#  'もどかしい 感情 × 100   ゾッコン ！ ！',
#  'みっともない ほど 君 に 夢中',
#  '宙ぶらりん の ハート どうし よう やる だけ やっ ちゃ え',
#  '伝え たい けど 伝え られ ない',
#  'もたもた し て たら 先 越さ れ ちゃう ソッコー ！ ！',
#  '嗚呼 、 悔しい けど ゾッコン な ん だ もん',
#  '桜 散っ てる 場合 じゃ ない から',
#  '春休み 直前',
#  'モラトリアムモラトリアムモラトリアム 中学生',
#  '放課後 ゲタ 箱 不意 に 君 が 現れ た',
#  '何 も 言え ない ちゃんと バイバイ し たかっ た',
#  'この 気持ち まるで 素数',
#  'に ー さん ご ー な な ！ ！',
#  '絶対 に 割り切れ ない よ',
#  'え た にて ぃ ー',
#  '新 学期 どぉ なっ ちゃう ん だろ',
#  '何 が なん でも 君 と 同じ クラス が いい',
#  '机 くっつけ て',
#  '教科書 忘れ た ぁ ～！！',
#  '面 と 向かっ て',
#  '集中 無 理っ ！ ！',
#  '居残り 授業 君 と 二 人 答え 合わせ を し たい',
#  'せめ ぎあうせめぎあう',
#  'ざわざわ',
#  'せめ ぎあうせめぎあう',
#  '葛藤 ！ ！',
#  'せ ・ め ・ ぎ ・ あ ・ う ・ せ ・ め ・ ぎ ・ あ ・ う',
#  'い て も たっ て も い られ ない',
#  'もどかしい 感情 × 100   ゾッコン ！ ！',
#  'みっともない ほど 君 に 夢中',
#  '宙ぶらりん の ハート どうし よう やる だけ やっ ちゃ え',
#  '伝え たい けど 伝え られ ない',
#  ...]

# %%
# !pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# Divide into train, dev, test

# %%
# Divide into train, dev, test
from sklearn.model_selection import train_test_split
train, dev_test = train_test_split(lines, train_size=0.8, random_state=4)
dev, test = train_test_split(dev_test, train_size=0.5, random_state=7)

with open("snow_t15_23_train.tsv", "w") as f:
    f.write("\n".join(train)+"\n")
with open("snow_t15_23_dev.tsv", "w") as f:
    f.write("\n".join(dev)+"\n")
with open("snow_t15_23_test.tsv", "w") as f:
    f.write("\n".join(test)+"\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=16'>17</a> # Divide into train, dev, test
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=17'>18</a> from sklearn.model_selection import train_test_split
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=18'>19</a> train, dev_test = train_test_split(lines, train_size=0.8, random_state=4)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=19'>20</a> dev, test = train_test_split(dev_test, train_size=0.5, random_state=7)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=20'>21</a>
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Divide into train, dev, test
from sklearn.model_selection import train_test_split
train, dev_test = train_test_split(sentences, train_size=0.8, random_state=4)
dev, test = train_test_split(dev_test, train_size=0.5, random_state=7)

with open("snow_t15_23_train.tsv", "w") as f:
    f.write("\n".join(train)+"\n")
with open("snow_t15_23_dev.tsv", "w") as f:
    f.write("\n".join(dev)+"\n")
with open("snow_t15_23_test.tsv", "w") as f:
    f.write("\n".join(test)+"\n")

# %%
# dataprocess
from txt2txt_ebc import data_process
df = data_process.to_df("../data/raw/ebc/*.txt")
df.shape
# Out:
# (6592, 3)

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer()
def gen_wakati_txt(txt: str):
    return ' '.join(t.tokenize(txt, wakati=True))
df['wakati_line'] = df['line'].apply(gen_wakati_txt)
sentences = df['wakati_line'].tolist()
sentences
# Out:
# まっ た 事',
#  '返し て くれる なら',
#  '愛し て みせる のに',
#  '愛し て い たい の に 消え て なくなっ て しまう な',
#  'やめ られ ない よ',
#  '感情 的 に はなれ ない 君 は 僕 と 踊れ ば いい',
#  'ずっと 僕 と ！',
#  '愛し て い たい の に 消え て なくなっ て しまう な',
#  '手 に 負え ない ぜ',
#  '最終 的 に 笑え ない 君 も 僕 も 踊れ ば いい',
#  'ずっと 僕ら 踊れ ば いい',
#  'silver   body   to   ride',
#  'digital   rock   &   roll   tune',
#  'baby   baby   baby',
#  'you   are   new - animal',
#  'heavy   metalic',
#  'digital   summer   beach',
#  'baby   baby   baby',
#  "I   don ' t   know   everything !!   all !!",
#  'do   mo   a   ri   ga   to   baby',
#  'bo   ku   ra   no   se   i   shu   n',
#  'do   i   ta   shi   ma   shi   te   baby',
#  'bo   ku   ni   ma   ka   se   na   yo',
#  'super   psychic',
#  'sun   sun   sun   sun   sun   ...',
#  'baby   island',
#  'ge   -   ge   -   generation   X',
#  'do   mo   a   ri   ga   to   baby',
#  'bo   ku   ra   no   se   i   shu   n',
#  'do   i   ta   shi   ma   shi   te   baby',
#  'bo   ku   ni   ma   ka   se   na   yo',
#  'do   ko   ma   de   to   be   ru   ka',
#  'te   a   shi   wo   po   no   po   no',
#  'so   n   na   ko   n   na   " a   ri   ga   to "',
#  'ki   mi   wa   bo   ku   no   mo   no',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  'do   mo   a   ri   ga   to',
#  'do   i   ta   shi   ma   shi   te',
#  '｢ 90 ｣｢ 91 ｣｢ 92 ｣｢ 93 ｣｢ 94 ｣｢ 95 ｣｢ 96 !!｣',
#  "bye   bye ('   o   '   )",
#  'チェケラッチョ',
#  'YO   DJ',
#  '何故か 鳴ん なかっ た アラーム',
#  '開か ず 踏切 閉まる ドア',
#  '何故か 上がん ない ウダツ',
#  '分かん ない 英文 ギブ し て 、 sleeping   sleeping',
#  '夢 の 中 なら ほら',
#  'かなり 無茶 め な シナリオ も',
#  'したい 放題 だっ た のに',
#  'ガ ツン おでこ に チョーク が 飛ん で き た',
#  '根拠 は 無い けど 大声 で 歌え ば 晴れる や',
#  'ただ で さえ 蒸し暑い 毎日',
#  'ハート ウォーミング は お呼び じゃ ない',
#  'いつの間にか やぶれ 捨て た 無 遅刻 無 欠席 スローガン',
#  'そん 代わり 大 親友   and   take   care   see   you   放課後 に また',
#  '居眠り ほっぺ の 跡 で トピック 話題 を さらお う',
#  '照り付ける 日差し 教室 は もう ちょっと で ブラジル',
#  'はじまり は ブラジル',
#  'おおかた ブラジル',
#  'YO   DJ',
#  '上書き さ れ て いく 最高 気温',
#  '反比例 下がる やる気 が どんどん',
#  'し た たた たる 汗 炭酸 飲み た ひ',
#  '干からび た ミミズ マジ に シンパシー',
#  'いち おく よん せん きゅう ひゃく メートル',
#  '太陽 発 校庭 経由 私',
#  '着 慣れ た 夏服 に ため息 ひとつ',
#  'A . S . A . P チャイム !',
#  '意味 なんて 無い けど それでも 今日 も 走る よ',
#  'ただ で さえ バテバテ の 季節 に',
#  'ハート ウォーミング は お呼び じゃ ない',
#  '下駄 箱 の 奥 の 方 に 忘れ て た 無 欠席 スローガン',
#  'そん 代わり 大 親友   and   take   care   see   you   放課後 に また',
#  '宿題 は ご飯 の 後 で メール 打ち ながら ゴロゴロ',
#  'とか 言い つつ も 明日 は プール アリ おおよそ ブラジル',
#  '三 段 重ね アイスクリーム',
#  '扇風機 に 向かっ て スクリーム ( A ” h ” h ” h ” h ” h ” )',
#  '蚊 に 刺さ れ て マジカチン',
#  '頭 突き の ひとつ でも か まし て やり たい',
#  'いつの間にか やぶれ 捨て た   無 遅刻 無 欠席 スローガン',
#  'そん 代わり   大 親友   and   take   care   see   you   放課後 に また',
#  '居眠り ほっぺ の 跡 で   トピック 話題 を さらお う',
#  '照り付ける 日差し   そこ どこ   ここ どこ   こりゃ ほぼ ブラジル',
#  'ほぼ ほぼ ブラジル',
#  'となり は コロンビア',
#  '君 と 僕 の あの 日々 が',
#  'いつも 強く つながっ てる よ',
#  'アイムサーチング   アイムサーチング',
#  'この 先 の 光 に   向かっ て ゆく なら',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '海底 に 潜む   シーラカンス',
#  'ゆっくり と 進化   照らし 出す',
#  '神 が いる として も   い ない として も',
#  '止め たく ない ん だ   僕ら の ストーリー',
#  'アイムサーチング   アイムサーチング',
#  '共に この 想い   あたため て ゆく から',
#  'PLAYBACK   PLAYBACK',
#  '願 わく ば   今 は そば に い て',
#  'PLAYBACK   PLAYBACK',
#  '生まれ変わっ て も   そう 君 の まま で い て',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '再生',
#  '感じとれる   この 先 の 光   見 に 行こ う',
#  'PLAYBACK   PLAYBACK',
#  '願 わく ば   今 は そば に い て',
#  'PLAYBACK   PLAYBACK',
#  '大人 に なっ て も   そう 君 の まま で い て',
#  'PLAYBACK   PLAYBACK',
#  '夢 叶う 時間 ( とき ) 限ら れ て い て',
#  'PLAYBACK   PLAYBACK',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  '君 に 幸 あれ   さあ   天 高く 昇れ',
#  'Uuu',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  '新しい 季節 巡り',
#  '揺るぎない この 想い',
#  '窓 を 開け たら すぐ に',
#  '君 の もと へ 飛び込む よ',
#  '始めよ う 今 この 場所 で',
#  'メラメラ 燃やす 想い',
#  'はち切れ そう な 憂鬱 に',
#  'ハッピー な クラッカー 打ち込ん で',
#  'ねぇ 言葉 じゃ 照れ ちゃう よ',
#  'ごまかし ちゃい そう で',
#  'ねぇ その 手 を 握り',
#  'ステージ に 立っ て 奏でよ う',
#  'あぁ 今 は この リズム に 乗っ て',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '数え て み ましょ 羊 さん',
#  'あっち の 夢 は 見る けど',
#  'こっち の 夢 を 叶える の',
#  '今 すぐ 全 速 前進 で',
#  'ねぇ 涙 が 溢れ て',
#  '濡らし た あの 日',
#  'ねぇ 宝物 に なっ て',
#  'この 背中 を 押し て くれる',
#  'あぁ 今 も この リズム に ノ って',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '「 私 もう 迷わ ない ！   みんな ー いく よっ ！ 」',
#  'Kick   and   punch   で   We   win ！',
#  'Chop   and   stick   で   Eat   in ！',
#  'Kick   for   kick   は   Win - win ！',
#  'チャンス は どこ ？   Checking ！',
#  '見つけ て   Getting ！',
#  'Big   wave 到来   Swimming ！',
#  'あぁ あの 頃 の 私 たち は きっと',
#  '大切 な 事 を 見失っ て い た ね',
#  'あぁ これから は 誰 に も 負け ない よ',
#  'あなた が くれ た 魔法',
#  '光 の 挿す 方 へ と',
#  'あぁ 今 は この リズム に 乗っ て',
#  '心 、 体 中 で 音 を 伝える から',
#  'あぁ 君 に 届く まで 歌う よ',
#  '世界中 に 私 たち 届け たい もの が ある の',
#  '「 曖昧 」 なんて kick   and   punch で WIN ！ ！',
#  '止まら ない king   story',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら ほら   hot   up ！ ！ ！',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  '曖昧 な んじゃ ピーポー 無 関心',
#  'Da ！   Ka ！   Ra ！',
#  'Fly   high テンション 、 フィーバー で Party ！ ！',
#  'ほら   ほら   hot   up ！ ！ ！',
#  'さあ さ みんな よっ て らっしゃい 小麦 ふっ て パン パンパン',
#  '揚げる ん だ エビ フライ どんと 行っ ちゃっ て',
#  'エビ に 恋せよ 乙女 でっかい でっかい の 大好き',
#  '洋食 の 王様 だ ワオ !',
#  '( サクサク 揚げろ 揚げろ 揚げろ )',
#  'ゴクリ 舌なめずり ( ゴクリ )',
#  'みんな テンション 上げ 上げ ( 上げ 上げ )',
#  'パーティー ムード なんか いい ぞ !',
#  'それ っ い !',
#  '( え ～ じゃ ない ええ じゃ ない じゃ ない )',
#  'ロブスターオマールエビ 浮気 し ちゃい そう',
#  'でも 君 に 一途 だ よ',
#  'サクサクプリプリプリ',
#  'パリパリカリカリカリ',
#  'なんて なんて 美味しい の 早く 早く フライ !',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'エビ フライ 揚げろ 揚げ 揚げ ジュワジュワジュワ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと テンション',
#  'グイグイグイ 上げ て',
#  '挙げ 挙げ 挙げ 挙げ 挙げ 挙げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケングー !( あいこ ～!)',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  'オードブル で 主役 フライ 級 の チャンピオン',
#  '学園中 人気 沸騰 ワオ !',
#  '( テンション 上がる 上がる 上がる )',
#  '熱い 油 の 中 ( あ ち ゅい )',
#  'なんて 君 は たくましい ( たくましい )',
#  '愛し てる でも 食べ ちゃう ぞ !',
#  '( え ～ じゃ ない ええ じゃ ない じゃ ない )',
#  '焼い ちゃ ダメ 煮 て も ダメ もっと 美味しく し て',
#  'こんがり と キツネ 色',
#  'サクサクプリプリプリ',
#  'パリパリカリカリカリ',
#  'サクサクプリプリプリエビエビエビフライ',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  'エビ フライ 高く 高く 高く フライフライフライ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと もっと',
#  'サクサク サク 揚げ て',
#  '挙げ 挙げ 挙げ 挙げ 挙げ 挙げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケンチョキ !( 負け た !)',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  '大好き ～ ジュワ ～ 美味しい ～',
#  '揚げ て 上げ て 揚げ て 上げ て',
#  '揚げ て 上げ て 揚げ て 上げ て',
#  '真っ黒 け っけ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'エビ フライ 揚げろ 揚げ 揚げ ジュワジュワジュワ',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'もっと テンション',
#  'グイグイグイ 上げ て',
#  '上げ 上げ 上げ 上げ 上げ 上げろ',
#  '拳 挙げろ 挙げろ 挙げろ ジャンケン パー !( 勝っ た ～!)',
#  '揚げ 揚げ 揚げ 揚げ 揚げ 揚げろ',
#  'ジュワジュワジュワジュワジュワジュワ',
#  '揚げろ !   揚げろ !( エビ フライ )',
#  'さあ さ みんな よっ て らっしゃい 小麦 ふっ て パン パンパン',
#  '揚げる ん だ エビ フライ 全部 食べ ちゃっ て !( ジュワ ～)',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'お ばあちゃん だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  '高校生 だって 中学生',
#  'いつ でも   ( いつも )   こうして   ( みんな )',
#  'バカ みたい に 遊ん で たい な',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'ヲタ さん だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'スタッフ さん も 中学生',
#  'ずーっと ね   ( ずーっと )   みんな と   ( ここ で )',
#  '今 の まんま 笑お う ね !',
#  'ほら 聞こえ て き まし た 下校 の ベル です',
#  '本日 これ にて おしまい',
#  '忘れ物 せ ず に 帰り ましょ',
#  '少し さみしい な 下校 の ベル です',
#  'また 次回 お 逢い し ましょ う',
#  '恵比寿 中学 で 永遠 に 中学生 !',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  'いくつ だって 中学生',
#  'ち ゅっちゅっちゅっちゅっちゅっ 中学生',
#  '気分 次第 中学生',
#  'どんなに   ( いつか )   大きく   ( なっ て も )',
#  'この 気持ち 忘れ ない',
#  'せ ー の',
#  'キンコンカンコンキンコンカンコン 下校 の ベル です',
#  '初心 忘れる べから ず',
#  '全然 エラく も ない です が',
#  'おわり の おしらせ 下校 の ベル です',
#  '次 の 登校 日 い つ でしょ ね',
#  'ホームページ チェック し て ね 永遠 に 中学生 !',
#  '今日 は 来 て くれ て ほんとに ありがとう !',
#  'ありがと !',
#  '聞こえ て き まし た 下校 の ベル です',
#  '本日 これ にて おしまい',
#  '忘れ物 せ ず に 帰り ましょ',
#  '少し さみしい な 下校 の ベル です',
#  'また 次回 お 逢い し ましょ う',
#  '恵比寿 中学 で 永遠 に 中学生 !',
#  '「 歯磨 け よー 」 「 宿題 しろ よー 」 「 気 を つけ て 帰れ よー 」',
#  '「 いい 夢みろ よー 」 「 お 父 さ ー ん 」',
#  '「 他 の 現場 も 行け よー 」 「 風邪 ひく な よー 」 「 チョット だけ よー 」',
#  '「 ファイト いっ ぱ ー つ 」 「 物販 も よろしく ー 」',
#  '永遠 に 中学生 !',
#  '「 みなさま ごきげんよう !!」',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  'ねぇ さっき 全然 興味 が ない って 言っ て た のに',
#  'どうして み て ん の ?   周辺 視覚 で',
#  'セクシー 仙人',
#  'カンフー 万 人',
#  '今 は もはや パンダ な 気分 ( き もち ) の 三 人',
#  'そんな まさか',
#  'Holiday',
#  'ちく わ ぶ くわえ ながら 柔軟 体操',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  '友人 と ベンチ',
#  '最高 の ランチ',
#  '最初 の 3 年 の 記憶 は 白紙',
#  '気さく に JUMP !!',
#  '町 へ 続く 道 と 逆 の 道',
#  '身振り 手振り で 渡れる 世界',
#  'オーロラ',
#  'かまぼこ の 味 が する アジア の グルメ',
#  'ちゃん ちゃ ら 可笑しく   ババンバン',
#  'とくに 意味 など ない けど   ババンバン',
#  '勝手 に ふわふわ し ちゃい やん ば かん',
#  '君 が 桟橋 の 向こう 側 から',
#  '一所懸命 手 を 振る 姿 が',
#  '背後 の 背景 に なじみ',
#  '僕 は いつのまにか 空 を かじり',
#  '枯れ は の 日々 を くぐり抜け て',
#  '気まぐれ Rally - Ho',
#  '君 が 桟橋 の 向こう 側 から',
#  '一所懸命 手 を 振る 姿 が',
#  '背後 の 背景 に なじみ',
#  '僕 は いつのまにか 空 を かじり',
#  '枯れ は の 日々 を くぐり抜け て',
#  '気まぐれ Rally - Ho',
#  'ちゃんばら おやじ と お ばあちゃん',
#  '頭 から 血 流し てる こりゃ いかん',
#  'チンピラ イライラ   疎外 感',
#  'お 肌 つるつる する の か な ? 白湯',
#  'メロス の 泉 を 探し て',
#  '北 、 南 、 東 、 西   羽ばたい て',
#  'たま に は 大胆 か まし て   いま',
#  '突撃 いたし ます る よ',
#  '突撃 いたし ます る よ',
#  '突撃 いたし ます る よ',
#  '',
#  'おばけ   おばけ   おばけ が くる ぞ !',
#  'に げろ   にげろ   追いつか れる ぞ !',
#  'やばい   やばい   取り 憑かれる ぞ !',
#  'ぎゃ ーーーーー !',
#  '真夜中   真夏 に   マジ でき も だ めし',
#  '夏 だ と いう のに   なに よ   この 寒気 ｡｡｡',
#  'おばけ とか   いる わけ ない しっ !',
#  '何 より も   科学 的 じ ゃないっっ !',
#  '白い 服   ずぶ ぬれ の 髪',
#  '笑っ てる   あの 人 は   誰 な の !?',
#  '臨 ・ 兵 ・ 闘 ・ 者 ・ 皆 ・ 陣 ・ 列 ・ 在 ・ 前',
#  'って ぜんぜん   効か ない じゃん !!',
#  'お じゅず',
#  'だめ だ こりゃ',
#  '囲ま れ ちまっ た',
#  '戦う しか ない',
#  '',
#  'ワーオ   ワーオ   ワオ   ワーーオ',
#  'そ ー めん',
#  'ひやそ ー めん !',
#  'はい !',
#  'それ ! それ ! それ ! それ !',
#  'それ ! それ ! それ ! それ !',
#  '',
#  '幽霊 なんか   ぶっとばせ !!',
#  '延髄 蹴り で   けっとばせ !!',
#  '女の子 を   なめ ない で !!',
#  'ママ の 方 が   よっぽど 怖い わ',
#  'ゴースト なぞ   ぶっとばせ !!',
#  'せ いけん 突き で   ふっとば せ !!',
#  'ケンカ 上等   負け ない ぜ !!',
#  'たたる 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  'エビ 中   ゴーストバスターズ',
#  '',
#  'ゾンビ   ゾンビ   ゾンビ も き た ぞ !',
#  'に げろ   にげろ   追いつか れる ぞ !',
#  'やばい   やばい   噛み付か れる ぞ !',
#  'ぎゃ ーーーーー !',
#  '部活 の 帰り   真っ暗   8 時 過ぎ',
#  '近道   小道   抜け道   外人 基地',
#  '曇り空   急 に 雷',
#  '真っ 二つ   ケヤキ が 割れる',
#  'もぞもぞ と   ゾンビ が 動く',
#  '',
#  'あり え ない っ !!   夢 か 幻 だ わ ｡｡｡',
#  "Oh   my   God !   Why   don ' t   you   save   me   new ?",
#  'って 英語 通じ ます かぁ ?',
#  'ドロドロ',
#  'ぐちゃぐちゃ',
#  'だめ だ こりゃ',
#  '逃げ場 ふさが れ た',
#  'やっ ちゃ い ましょ う か',
#  'ワーオ   ワーオ   ワオ   ワーーオ',
#  'あー ぶら   かた ぶら   びばのんのん !!',
#  '',
#  'ゾンビ なんか   ぶっとばせ !!',
#  '飛び ひざ 蹴り で   けっとばせ !!',
#  'ニッポン 女子   なめ ない で !!',
#  '先生 の 方 が   よっぽど 怖い わ',
#  'アン   ドュー   トロ ワ ☆   で   ぶっとばせ !!',
#  'ラリアット で   ふっとば せ !!',
#  '百戦錬磨   負け ない ぜ !!',
#  '襲う 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  '今夜 は スリラー   スリラー ナイト',
#  'アーメン',
#  'そ ー めん',
#  'ひやそ ー めん !',
#  'はい !',
#  'それ ! それ ! それ ! それ !',
#  'それ ! それ ! それ ! それ !',
#  '幽霊 なんか   ぶっとばせ !!',
#  '延髄 蹴り で   けっとばせ !!',
#  '女の子 を   なめ ない で !!',
#  'パパ の 方 が   ある 意味 怖い わ',
#  'ゴースト なぞ   ぶっとばせ !!',
#  'せ いけん 突き で   ふっとば せ !!',
#  'ケンカ 上等   負け ない ぜ !!',
#  'たたる 相手   間違え た みたい ね ?',
#  'ぎゃ ー お   ぎゃ ー お   ぎゃ ー お   ぎゃ ー お',
#  'ぎゃお   ぎゃお   ぎゃ ー',
#  'エビ 中   ゴーストバスターズ',
#  'いつか 語り合っ た 想い を 抱え',
#  '約束 の 場所 たどり着く まで',
#  '強がる ほど に 涙 は 溢れ',
#  '永遠 じゃ ない 今 が 始まる',
#  '止まら ない で 胸 の 奥',
#  'しまい こん だ 色とりどり の 光',
#  '忘れ ない よう に 進め ば いい',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  '笑え ない 日 だって ある けど',
#  '君 の 全て が 明日 を てらす から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  '抱え きれ ない ほど の 願い事',
#  '全て が 叶わ ない の 分かっ てる',
#  'それでも 手 を 引い て くれる 君 が いる から',
#  'また 歩き 出せる よ',
#  'いつも どおり に',
#  '笑い あっ た いくつ も の',
#  '思い出 や 切ない 痛み も',
#  '忘れ ない よ この 空 に 色 を 添え て',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  'こぼれ そう な 涙 拭う 手',
#  '君 の ぬくもり',
#  'すべて 知っ てる から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  '曖昧 な 日々 を 繋い でる',
#  '長く 続く 足跡',
#  'どこ まで 続く だろ う',
#  'どこ まで 行ける だろ う',
#  '確か な こと は 何 も ない けど',
#  '怖く ない',
#  '止まら ない で 胸 の 奥',
#  'しまい こん だ 色とりどり の 光',
#  '忘れ ない よう に 進め ば いい',
#  'Wow   Wow   Wow',
#  'ねぇ 信じ て',
#  '笑え ない 日 だって ある けど',
#  '君 の 全て が 明日 を てらす から',
#  'Wow   Wow   Wow',
#  'Say   Yeah   Say   Yeah',
#  '自分 だけ の 明日 探し て',
#  'Say   Yeah   Say   Yeah',
#  '君 の まま で',
#  'Say   Yeah   Say   Yeah',
#  'さあ 、 Say   Yeah   Say   Yeah',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '声 を 出し て よ',
#  'Hey ！ 加速 する DAYS 加熱 する BODY',
#  '私 の 愛 受け取れ ない ？   ( イイ ヨー ！ ！)',
#  '青二才 で も この 際',
#  '火遊び し て みる ？   By   my   side',
#  'Time   goes   by 磨け ば 輝く っし ょいけるっしょ ！',
#  'そんな エモ め の 土曜 も Change   up',
#  'ちょっと サビ まで stay   up',
#  '大器晩成 さ',
#  'これから もっと 輝い て ゆく の',
#  '愛 と 正義 さ',
#  'ブチ か ます から つい て き て',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ さあ   SHAKE ！   SHAKE ！',
#  'ハイ ！ 格好 の STUDY 思考 の SWAY',
#  '楽しく ない なら 用 は ない',
#  '本日 は 膝 上 20 cm (！？)',
#  'でも 無敵 の 私 は 怯ま ない',
#  '髪 も バッチリ でも 少し Chilly',
#  '何 も 知ら ない から 終われ ない',
#  '純情 ・ 友情 ・ バカ 参上 ( ハァーイ ！！)',
#  'まだ 知ら ない 天井',
#  '絶体絶命 の',
#  '状況 も もっと 楽しん で ゆく の さ',
#  '笑止千万 さ',
#  'かっ飛ばす から つい て き て',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ 今   SHAKE ！   SHAKE ！',
#  'HEY ,   GUYS ！   BOYS   AND   GIRLS',
#  '今 から 言う こと よく 聞き な',
#  '命 の 限り 手 挙げろ',
#  'つい て こ れる やつ は つい て 来い',
#  '私 たち の 姿 よく 見 とけ',
#  '半端 な やつ は 今 帰り な',
#  'さあ 、 いけん の か ？ やれん の か ？',
#  '分かっ た やつ は 返事 しろ',
#  '私 、 この まま',
#  '何 も 知ら ない まま 歩い て いく',
#  'スキップ し て さようなら',
#  '始まっ て ない から 終われ ない',
#  'そう やっ て Hey ！( Hey ！)',
#  '黙っ て い ない で さ',
#  '声 を 出し て よ ほら ！   SHAKE ！   SHAKE ！',
#  '',
#  '放課後   ど しゃぶり の 雨 の 中 で',
#  '傘 も ささ ず 立ちすくむ',
#  '彼女 と 彼 が 付き合っ てる こと',
#  '初めて 聞い て しまっ た',
#  '',
#  '入学 式 から 今日 まで ずっと',
#  '隠し て い た この 気持ち',
#  '',
#  '誰 に も ゆずる わけ に いか ない と',
#  '心 に 決め て た のに',
#  '',
#  '｢ 彼 の こと が 好き   応援 し て よ ね !!｣',
#  '( セリフ )',
#  '｢ 彼 の こと が 好き な ん だ   応援 し て くれる よ ね ?｣',
#  '突然   打ち明け られ た あの 日',
#  '友情   愛情   選ぶ こと 出来 なく て',
#  '作り笑い',
#  'し て い た   REGRET !!',
#  '',
#  '泣け ど 叫べ ど   戻せ ない   Destiny',
#  'こんなに   好き な のに   想い は 届か ない',
#  '流す 涙 が   雨 に 消え て いく',
#  '二 人 の 幸せ を   永遠 に 祈る よ',
#  "I   Love   you   でも   It ' s   Too   Late",
#  '嗚呼   ど しゃぶり リグレット',
#  '',
#  '放課後   ど しゃぶり の 雨 の 中 で',
#  '肩 寄せ あい 歩い てる',
#  '周り も 見え ない   二 人 の 世界',
#  '憧れ の 相合傘',
#  '',
#  'ふざけ て じゃれ あう   彼 と 彼女 の',
#  '見 た こと ない その 笑顔',
#  '',
#  'ほんと なら 私 が すぐ 隣 で',
#  '笑っ て た はず な のに',
#  '',
#  '｢ 私 も 好き な の   負け ない ん だ から !!｣',
#  '( セリフ )',
#  '｢ 私 も 好き な の ! 負け ない ん だ から !!｣',
#  '素直 に 言え たら よかっ た のに',
#  '勇気 が 足り ず に 気持ち ごまかし て たら',
#  '愛情 も',
#  'なくし た   REGRET !!',
#  '',
#  '寝 て も 覚め て も   止まら ない 涙',
#  '神様   教え て よ   夢 は 叶わ ない の ?',
#  'もしも 時間 を   戻せる の なら ば',
#  'あなた へ この 想い   全身 で 届けよ う',
#  "I   Love   You ・ ・ ・   You   Don ' t   Love   Me .",
#  '嗚呼   ど しゃぶり リグレット',
#  '初めて いだい た 恋心',
#  '忘れ られる わけ が ない じゃ ない',
#  'この 胸 の 痛み 思い出 に   変わる の か な',
#  '嗚呼   雨 が やま ない よ',
#  '',
#  '泣け ど 叫べ ど 戻せ ない   Destiny',
#  'こんなに 好き な のに   想い は 届か ない',
#  '',
#  '流す 涙 が   雨 に 消え て いく',
#  '二 人 の 幸せ を   永遠 に 祈る よ',
#  "I   Love   You   でも   It ' s   Too   Late",
#  '嗚呼   ど しゃぶり リグレット',
#  'ドン どど ・ どん どど ・ ドーン っ ！',
#  '打ち上げろ 花火',
#  '寝 て も 覚め て も',
#  '終わら ない ジャンボリー',
#  'なぜ そこ まで と わけ わから ん ほど の 汗 と 努力 で',
#  '掘り出し物 の 夢 を 磨き 上げ ここ まで き た',
#  'ちょっと 待っ て あっ ため た',
#  'ヴォンゴレー ！ 食べる から',
#  '銀河系 中 同時 進行 頭上 げろ ！',
#  '土星 の 輪っか な 街 で 君 と スウィーテスト な 多忙',
#  'ここ で 会っ た が 百 年 目 ね 組ん ず 解れ つ',
#  '25 . 6 時間 じゃ 足り ない',
#  '水金 地 火 木 な エヴリデイ',
#  '君 と 出会え た 奇跡 に',
#  'ナ・ナ・ナ・ナ・ナ・ナ・ナ・ナ・ナマステ ！ ナマ ステ ！',
#  'ワオ ！',
#  'ダイヤモンド が 眠る 国 が ある 行っ て み たい な',
#  'オイミヤコン 村 は 、 マイナス 71 度 めっちゃ 寒い ！',
#  'テン ガロン で バンガロー に',
#  'ボンソワール ！ 叶う まで',
#  '頑張ろ う ぜ 皆 、 バンジョー ！ かき鳴らし て ！',
#  'トロピカル な 水着 で   Yes ！ ！ 君 と スウィーテスト な 多忙',
#  'ナビ も つけ ず に 回り道 で 全部 想い出',
#  '土星 の 輪っか な 街 で 君 と スウィーテスト な 多忙',
#  '月 の 光 に 溶け た ぼく ら 歌う 都々逸 ！',
#  '音楽 室 の 壁 に 飾ら れ た 肖像 画',
#  '一 人 だけ 校長 先生 に',
#  '似 てる の が ド・ド・ド・ド・ドビュッシー ！ ドビュッシー ！',
#  'ワオ ！',
#  'ドン どど ・ どん どど ・ ドーン っ ！',
#  '打ち上げろ 花火',
#  '寝 て も 覚め て も',
#  '終わら ない ジャンボリー',
#  'ゴー ！ Ready ゴー ！ Ready ゴー っ ！',
#  '共に 行こ う ！ 未だ 見 ぬ 世界 へ ！',
#  'ゴー ！ Ready ゴー ！ Ready ゴー っ ！',
#  'いざ 、 君 と',
#  'スウィーテスト・ 多忙 な デイズ ！',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '恵比寿 駅 発 の 土星 行き',
#  '加速度 ぐんぐん 上げ ましょ う',
#  'テスト の 範囲 は 小宇宙',
#  '居残り 確定 明日 の 授業',
#  'ゆらゆら ゆらゆら 流れ着き',
#  '今日 も 宿題 は 後回し',
#  '水金 地 火 木 土 天海 ( 冥 )',
#  '放課後 カラオケ よそ の 惑星',
#  'あぁ 麗し の ブラウニー',
#  '( ひとつ ふたつ もう 止まら ない )',
#  'あれれ ？ ちょっと もしか し たら',
#  'カロリー オーバー じゃん ？ ！',
#  '( 甘い もの なら 別 次元 )',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '地球 は どうやら 忙しい',
#  'ハイファイワイファイ もう いっぱい',
#  '明治 大正 昭和 平成',
#  '文明開化 の 音 が する',
#  'あぁ 追憶 の フィナンシェ',
#  '( もっと キミ の 声 聞か せ て よ )',
#  'ちょっと ！ すぐ に 交信 する の やめ て よ 火星 人',
#  '( ぴぴぴぴぴぴぴぴぴぴぴぴ )',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  'ずっ き ゅんずっきゅん',
#  '胸 に くる',
#  'この 気持ち の 名前 を 教え て',
#  'どっ き ゅんどっきゅん',
#  '続い てる',
#  'ときめき の 速度 は 加速 中',
#  'ずっ き ゅんずっきゅん',
#  '明日 の こと',
#  '忘れ て とりあえず 踊り ましょ う',
#  'どっ き ゅんどっきゅん',
#  '「 もしか し て ： 」',
#  'わたし 未 確認 中学生   X',
#  '夜 の クラブ ビジョン 潜め た   Rainbow   Gray に',
#  '遠ざかる デジャブ と 近づく 夏 の 鼓動',
#  'もう 切ない ほど 燃え だそ う と し てる の',
#  'いつか ら か 時めい て 何気ない 日常 まで',
#  'シングル TONE で お願い 「 好き 」 の 響き が 聞き たく て',
#  'ノイズ さえ も ハモ り だす 予感 が する の よ',
#  'シングル TONE で お願い 過去 も これから も 刻み だす',
#  '雨 音 に まどろん で 二 人 の 未来 回り だす',
#  'ふい に すれ違っ た 心 の 行方 さえ',
#  'その 素振り 隠し て あなた は 目 を そらす',
#  'ほら いつのまにか 二 人 を 繋げ て く',
#  '当たり前 に 流れ て く 何気ない 日常 から',
#  'シングル TONE で お願い 儚く 砕け そう な ハーモナイズ',
#  'あなた と は 突き抜ける 予感 が する の よ',
#  'シングル TONE で お願い 胸 の 隙間 から 弾け 飛ぶ',
#  'いつか ら か 時 を 超え て 二 人 は 未来 作りだそ う',
#  '大好き な 理由 を 簡単 な 言葉 で 伝え たい',
#  'そう 私 を 信じよ う',
#  'シングル TONE で お願い 「 好き 」 の 響き が 聞き たく て',
#  'ノイズ さえ も ハモ り だす 予感 が する の よ',
#  'シングル TONE で お願い 過去 も これから も 刻み だす',
#  '雨 音 に まどろん で 二 人 の 未来 回り だす',
#  'なんて 切ない ん だろ う 時間 が 出し た 答え が 胸 を 締め付ける',
#  'おはよう の 声 と 頭 に ポ ン と 置か れ た 手 は 大人 の 香り が し てる 気 が し た',
#  '教室 の 窓 いつも 見 て た あなた は きっと 今 も 気づい て ない よ',
#  'さようなら 春 が 近づい て あなた に 会え なく なる ん だ ね',
#  '伝え たい この 気持ち だけ が ずっと 言え ない まま でし た',
#  '本当は すごく 寂しい ん だ よ ほら ね すぐ に 涙 が 溢れ た',
#  'なんて 切ない ん だろ う 当たり前 の 毎日 が 変わっ ちゃう みたい だ',
#  '放課後 の 度 に 探し まわっ た 廊下 は もう 思い出 の 色 に 深く 染まっ た',
#  '二 人 で 歩く 時間 も 無くなる 事 想像 すら も し て い なかっ た',
#  'さようなら 叶わ ない 恋 と 知っ て も 想い 続け てる',
#  '伝え たい この 気持ち だけ は 最後 まで 言え ない まま で いい',
#  'あの 笑顔 思い出す 度 に 胸 の 奥 が チクリ と 疼い た',
#  '優しい 記憶 消え ない よう に',
#  '哀しみ だけ を ぎゅっと 胸 に 閉じ込め た なら',
#  '前 だけ を 向い て 行ける ？',
#  'さようなら いつか 話す よそ の 時 まで',
#  '帰り道 一 人 で そっと つぶやく 「 好き だ よ 。 きっと それでも 」',
#  'さようなら 春 が 近づい て あなた に 会え なく なる ん だ ね',
#  '伝え たい この 気持ち だけ が ずっと 言え ない まま でし た',
#  '本当は すごく 寂しい ん だ よ ほら ね すぐ に 涙 が 溢れ た',
#  'せめ ぎあうせめぎあう',
#  'ざわざわ',
#  'せめ ぎあうせめぎあう',
#  '心 が',
#  'せ ・ め ・ ぎ ・ あ ・ う',
#  '春休み モラトリアム 中学生',
#  'こ いっ ！ ！   こ いっ ！ ！   ゾッコン ！ ！',
#  'こ いっ ！ ！   こ いっ ！ ！   ロックオン ！ ！',
#  '心 の 筆箱 ガタガタ 落ち着か ない',
#  '授業 中 だって ギリギリ 見つめ てる',
#  'すれ違う 視線 希望 が 反比例',
#  '未だ 答え 「 Y ＝ X 」 の まま',
#  'この 気持ち まるで 素数 に ー さん ご ー な な ！ ！',
#  '絶対 に 割り切れ ない よ',
#  'え た にて ぃ ー',
#  '秘密 の 方程式',
#  '私 だけ に こっそり と 耳打ち し て',
#  '素っ気 ない 態度',
#  'そっぽ 向い ちゃっ て',
#  '好き の 裏返し ？ ！',
#  '超 前向き ！ ！',
#  '恋 の 面積 君 と 二 人 証明 し て み たい',
#  'せめ ぎあうせめぎあう',
#  'ぞくぞく',
#  'せめ ぎあうせめぎあう',
#  '妄想 ！ ！',
#  'せ ・ め ・ ぎ ・ あ ・ う',
#  'い て も たっ て も い られ ない',
#  'もどかしい 感情 × 100   ゾッコン ！ ！',
#  'みっともない ほど 君 に 夢中',
#  '宙ぶらりん の ハート どうし よう やる だけ やっ ちゃ え',
#  '伝え たい けど 伝え られ ない',
#  'もたもた し て たら 先 越さ れ ちゃう ソッコー ！ ！',
#  '嗚呼 、 悔しい けど ゾッコン な ん だ もん',
#  '桜 散っ てる 場合 じゃ ない から',
#  '春休み 直前',
#  'モラトリアムモラトリアムモラトリアム 中学生',
#  '放課後 ゲタ 箱 不意 に 君 が 現れ た',
#  '何 も 言え ない ちゃんと バイバイ し たかっ た',
#  'この 気持ち まるで 素数',
#  'に ー さん ご ー な な ！ ！',
#  '絶対 に 割り切れ ない よ',
#  'え た にて ぃ ー',
#  '新 学期 どぉ なっ ちゃう ん だろ',
#  '何 が なん でも 君 と 同じ クラス が いい',
#  '机 くっつけ て',
#  '教科書 忘れ た ぁ ～！！',
#  '面 と 向かっ て',
#  '集中 無 理っ ！ ！',
#  '居残り 授業 君 と 二 人 答え 合わせ を し たい',
#  'せめ ぎあうせめぎあう',
#  'ざわざわ',
#  'せめ ぎあうせめぎあう',
#  '葛藤 ！ ！',
#  'せ ・ め ・ ぎ ・ あ ・ う ・ せ ・ め ・ ぎ ・ あ ・ う',
#  'い て も たっ て も い られ ない',
#  'もどかしい 感情 × 100   ゾッコン ！ ！',
#  'みっともない ほど 君 に 夢中',
#  '宙ぶらりん の ハート どうし よう やる だけ やっ ちゃ え',
#  '伝え たい けど 伝え られ ない',
#  ...]

# %%
# !pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
import torch
torch.cuda.is_available()
# Out:
# True

# %%
def get_data_from_file(text, batch_size, seq_size):
    text = text.split()
    word_counts = Counter(text)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {k: w for k, w in enumerate(sorted_vocab)}
    vocab_to_int = {w: k for k, w in int_to_vocab.items()}
    n_vocab = len(int_to_vocab)

    print('Vocabulary size', n_vocab)

    int_text = [vocab_to_int[w] for w in text]
    num_batches = int(len(int_text) / (seq_size * batch_size))
    in_text = int_text[:num_batches * batch_size * seq_size]
    out_text = np.zeros_like(in_text)
    out_text[:-1] = in_text[1:]
    out_text[-1] = in_text[0]
    in_text = np.reshape(in_text, (batch_size, -1))
    out_text = np.reshape(out_text, (batch_size, -1))
    return int_to_vocab, vocab_to_int, n_vocab, in_text, out_text

    def get_batches(in_text, out_text, batch_size, seq_size):
    num_batches = np.prod(in_text.shape) // (seq_size * batch_size)
    for i in range(0, num_batches * seq_size, seq_size):
        yield in_text[:, i:i+seq_size], out_text[:, i:i+seq_size]
# Out:
#   File "<ipython-input-13-495505f6c618>", line 22
#     num_batches = np.prod(in_text.shape) // (seq_size * batch_size)
#               ^
# IndentationError: expected an indented block

# %%
def get_data_from_file(text, batch_size, seq_size):
    text = text.split()
    word_counts = Counter(text)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {k: w for k, w in enumerate(sorted_vocab)}
    vocab_to_int = {w: k for k, w in int_to_vocab.items()}
    n_vocab = len(int_to_vocab)

    print('Vocabulary size', n_vocab)

    int_text = [vocab_to_int[w] for w in text]
    num_batches = int(len(int_text) / (seq_size * batch_size))
    in_text = int_text[:num_batches * batch_size * seq_size]
    out_text = np.zeros_like(in_text)
    out_text[:-1] = in_text[1:]
    out_text[-1] = in_text[0]
    in_text = np.reshape(in_text, (batch_size, -1))
    out_text = np.reshape(out_text, (batch_size, -1))
    return int_to_vocab, vocab_to_int, n_vocab, in_text, out_text

def get_batches(in_text, out_text, batch_size, seq_size):
    num_batches = np.prod(in_text.shape) // (seq_size * batch_size)
    for i in range(0, num_batches * seq_size, seq_size):
        yield in_text[:, i:i+seq_size], out_text[:, i:i+seq_size]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
from collections import Counter
import os
from argparse import Namespace


flags = Namespace(
    seq_size=32,
    batch_size=16,
    embedding_size=64,
    lstm_size=64,
    gradients_norm=5,
    predict_top_k=5
)

# %%
def get_data_from_text(text, batch_size, seq_size):
    text = text.split()
    word_counts = Counter(text)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {k: w for k, w in enumerate(sorted_vocab)}
    vocab_to_int = {w: k for k, w in int_to_vocab.items()}
    n_vocab = len(int_to_vocab)

    print('Vocabulary size', n_vocab)

    int_text = [vocab_to_int[w] for w in text]
    num_batches = int(len(int_text) / (seq_size * batch_size))
    in_text = int_text[:num_batches * batch_size * seq_size]
    out_text = np.zeros_like(in_text)
    out_text[:-1] = in_text[1:]
    out_text[-1] = in_text[0]
    in_text = np.reshape(in_text, (batch_size, -1))
    out_text = np.reshape(out_text, (batch_size, -1))
    return int_to_vocab, vocab_to_int, n_vocab, in_text, out_text

def get_batches(in_text, out_text, batch_size, seq_size):
    num_batches = np.prod(in_text.shape) // (seq_size * batch_size)
    for i in range(0, num_batches * seq_size, seq_size):
        yield in_text[:, i:i+seq_size], out_text[:, i:i+seq_size]

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])

def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_file(
        flags.train_file, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, flags.initial_words, n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])

def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
        sentences, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, flags.initial_words, n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=172'>173</a> main()
#
# /workspace/notebooks/pytorch-gru-textgen.py in main()
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=112'>113</a>     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=113'>114</a>     int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
# ---> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=114'>115</a>         sentences, flags.batch_size, flags.seq_size)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=115'>116</a>
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=116'>117</a>     net = RNNModule(n_vocab, flags.seq_size,
#
# /workspace/notebooks/pytorch-gru-textgen.py in get_data_from_text(text, batch_size, seq_size)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=41'>42</a> def get_data_from_text(text, batch_size, seq_size):
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=42'>43</a>     text = text.split()
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=43'>44</a>     word_counts = Counter(text)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=44'>45</a>     sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=45'>46</a>     int_to_vocab = {k: w for k, w in enumerate(sorted_vocab)}
#
# AttributeError: 'list' object has no attribute 'split'

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])

def main(sentences):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
        sentences, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, flags.initial_words, n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
main(sentences)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=172'>173</a> main(sentences)
#
# /workspace/notebooks/pytorch-gru-textgen.py in main(sentences)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=112'>113</a>     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=113'>114</a>     int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
# ---> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=114'>115</a>         sentences, flags.batch_size, flags.seq_size)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=115'>116</a>
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=116'>117</a>     net = RNNModule(n_vocab, flags.seq_size,
#
# /workspace/notebooks/pytorch-gru-textgen.py in get_data_from_text(text, batch_size, seq_size)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=41'>42</a> def get_data_from_text(text, batch_size, seq_size):
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=42'>43</a>     text = text.split()
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=43'>44</a>     word_counts = Counter(text)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=44'>45</a>     sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=45'>46</a>     int_to_vocab = {k: w for k, w in enumerate(sorted_vocab)}
#
# AttributeError: 'list' object has no attribute 'split'

# %%
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.118081092834473
# Epoch: 2/200 Iteration: 200 Loss: 5.4558844566345215
# Epoch: 3/200 Iteration: 300 Loss: 4.535484790802002
# Epoch: 4/200 Iteration: 400 Loss: 4.146425247192383
# Epoch: 5/200 Iteration: 500 Loss: 3.8710508346557617
# Epoch: 6/200 Iteration: 600 Loss: 3.1155803203582764
# Epoch: 7/200 Iteration: 700 Loss: 3.0724966526031494
# Epoch: 8/200 Iteration: 800 Loss: 2.461953639984131
# Epoch: 9/200 Iteration: 900 Loss: 2.288709878921509
# Epoch: 11/200 Iteration: 1000 Loss: 2.032740831375122
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=172'>173</a> main(' '.join(sentences))
#
# /workspace/notebooks/pytorch-gru-textgen.py in main(sentences)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=164'>165</a>
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=165'>166</a>             if iteration % 1000 == 0:
# --> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=166'>167</a>                 predict(device, net, flags.initial_words, n_vocab,
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=167'>168</a>                         vocab_to_int, int_to_vocab, top_k=5)
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=168'>169</a>                 torch.save(net.state_dict(),
#
# AttributeError: 'Namespace' object has no attribute 'initial_words'

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])

def main(sentences):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
        sentences, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, '中学生', n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.115835189819336
# Epoch: 2/200 Iteration: 200 Loss: 5.495164394378662
# Epoch: 3/200 Iteration: 300 Loss: 4.523556232452393
# Epoch: 4/200 Iteration: 400 Loss: 4.231612205505371
# Epoch: 5/200 Iteration: 500 Loss: 3.8222827911376953
# Epoch: 6/200 Iteration: 600 Loss: 3.240931272506714
# Epoch: 7/200 Iteration: 700 Loss: 3.0822925567626953
# Epoch: 8/200 Iteration: 800 Loss: 2.409097194671631
# Epoch: 9/200 Iteration: 900 Loss: 2.144911527633667
# Epoch: 11/200 Iteration: 1000 Loss: 2.0145840644836426
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=172'>173</a> main(' '.join(sentences))
#
# /workspace/notebooks/pytorch-gru-textgen.py in main(sentences)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=165'>166</a>             if iteration % 1000 == 0:
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=166'>167</a>                 predict(device, net, '中学生', n_vocab,
# --> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=167'>168</a>                         vocab_to_int, int_to_vocab, top_k=5)
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=168'>169</a>                 torch.save(net.state_dict(),
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=169'>170</a>                             'checkpoint_pt/model-{}.pth'.format(iteration))
#
# /workspace/notebooks/pytorch-gru-textgen.py in predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=100'>101</a>     state_c = state_c.to(device)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=101'>102</a>     for w in words:
# ---> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=102'>103</a>         ix = torch.tensor([[vocab_to_int[w]]]).to(device)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=103'>104</a>         output, (state_h, state_c) = net(ix, (state_h, state_c))
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=104'>105</a>
#
# KeyError: '学'

# %%
breakpoint()
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.179258823394775
# Epoch: 2/200 Iteration: 200 Loss: 5.413080215454102
# Epoch: 3/200 Iteration: 300 Loss: 4.444156646728516
# Epoch: 4/200 Iteration: 400 Loss: 4.1922149658203125
# Epoch: 5/200 Iteration: 500 Loss: 3.822658061981201
# Epoch: 6/200 Iteration: 600 Loss: 3.1946470737457275
# Epoch: 7/200 Iteration: 700 Loss: 3.0932180881500244
# Epoch: 8/200 Iteration: 800 Loss: 2.570024013519287
# Epoch: 9/200 Iteration: 900 Loss: 2.372471570968628
# Epoch: 11/200 Iteration: 1000 Loss: 2.1434714794158936
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
#       <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=172'>173</a> breakpoint()
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=173'>174</a> main(' '.join(sentences))
#
# /workspace/notebooks/pytorch-gru-textgen.py in main(sentences)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=165'>166</a>             if iteration % 1000 == 0:
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=166'>167</a>                 predict(device, net, '中学生', n_vocab,
# --> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=167'>168</a>                         vocab_to_int, int_to_vocab, top_k=5)
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=168'>169</a>                 torch.save(net.state_dict(),
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=169'>170</a>                             'checkpoint_pt/model-{}.pth'.format(iteration))
#
# /workspace/notebooks/pytorch-gru-textgen.py in predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=100'>101</a>     state_c = state_c.to(device)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=101'>102</a>     for w in words:
# ---> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=102'>103</a>         ix = torch.tensor([[vocab_to_int[w]]]).to(device)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=103'>104</a>         output, (state_h, state_c) = net(ix, (state_h, state_c))
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=104'>105</a>
#
# KeyError: '学'

# %%
breakpoint()
len(sentences)
# Out:
# 6592

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])

def main(sentences):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
        sentences, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, '君', n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.233645439147949
# Epoch: 2/200 Iteration: 200 Loss: 5.5009965896606445
# Epoch: 3/200 Iteration: 300 Loss: 4.535221099853516
# Epoch: 4/200 Iteration: 400 Loss: 4.233177661895752
# Epoch: 5/200 Iteration: 500 Loss: 3.7097008228302
# Epoch: 6/200 Iteration: 600 Loss: 3.2010107040405273
# Epoch: 7/200 Iteration: 700 Loss: 3.1109278202056885
# Epoch: 8/200 Iteration: 800 Loss: 2.4518160820007324
# Epoch: 9/200 Iteration: 900 Loss: 2.392094850540161
# Epoch: 11/200 Iteration: 1000 Loss: 2.0709614753723145
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=172'>173</a> main(' '.join(sentences))
#
# /workspace/notebooks/pytorch-gru-textgen.py in main(sentences)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=165'>166</a>             if iteration % 1000 == 0:
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=166'>167</a>                 predict(device, net, '君', n_vocab,
# --> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=167'>168</a>                         vocab_to_int, int_to_vocab, top_k=5)
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=168'>169</a>                 torch.save(net.state_dict(),
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=169'>170</a>                             'checkpoint_pt/model-{}.pth'.format(iteration))
#
# /workspace/notebooks/pytorch-gru-textgen.py in predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k)
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=107'>108</a>     choice = np.random.choice(choices[0])
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=108'>109</a>
# ---> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=109'>110</a>     words.append(int_to_vocab[choice])
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=110'>111</a>
#      <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=111'>112</a> def main(sentences):
#
# AttributeError: 'str' object has no attribute 'append'

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])

def main(sentences):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
        sentences, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, ['君','が'], n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.077773571014404
# Epoch: 2/200 Iteration: 200 Loss: 5.513238906860352
# Epoch: 3/200 Iteration: 300 Loss: 4.5275654792785645
# Epoch: 4/200 Iteration: 400 Loss: 4.156939506530762
# Epoch: 5/200 Iteration: 500 Loss: 3.700721263885498
# Epoch: 6/200 Iteration: 600 Loss: 2.997450828552246
# Epoch: 7/200 Iteration: 700 Loss: 2.9341392517089844
# Epoch: 8/200 Iteration: 800 Loss: 2.4180829524993896
# Epoch: 9/200 Iteration: 900 Loss: 2.2233476638793945
# Epoch: 11/200 Iteration: 1000 Loss: 1.9419811964035034
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /workspace/notebooks/pytorch-gru-textgen.py in <module>
# ----> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=172'>173</a> main(' '.join(sentences))
#
# /workspace/notebooks/pytorch-gru-textgen.py in main(sentences)
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=167'>168</a>                         vocab_to_int, int_to_vocab, top_k=5)
#     <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=168'>169</a>                 torch.save(net.state_dict(),
# --> <a href='file:///workspace/notebooks/pytorch-gru-textgen.py?line=169'>170</a>                             'checkpoint_pt/model-{}.pth'.format(iteration))
#
# /opt/conda/envs/textgen/lib/python3.7/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     367             return
#     368
# --> 369     with _open_file_like(f, 'wb') as opened_file:
#     370         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#     371
#
# /opt/conda/envs/textgen/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     232 def _open_file_like(name_or_buffer, mode):
#     233     if _is_path(name_or_buffer):
# --> 234         return _open_file(name_or_buffer, mode)
#     235     else:
#     236         if 'w' in mode:
#
# /opt/conda/envs/textgen/lib/python3.7/site-packages/torch/serialization.py in __init__(self, name, mode)
#     213 class _open_file(_opener):
#     214     def __init__(self, name, mode):
# --> 215         super(_open_file, self).__init__(open(name, mode))
#     216
#     217     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoint_pt/model-1000.pth'

# %%
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.170069217681885
# Epoch: 2/200 Iteration: 200 Loss: 5.517542839050293
# Epoch: 3/200 Iteration: 300 Loss: 4.497864723205566
# Epoch: 4/200 Iteration: 400 Loss: 4.218200206756592
# Epoch: 5/200 Iteration: 500 Loss: 3.6400809288024902
# Epoch: 6/200 Iteration: 600 Loss: 3.0410706996917725
# Epoch: 7/200 Iteration: 700 Loss: 2.9108495712280273
# Epoch: 8/200 Iteration: 800 Loss: 2.4224090576171875
# Epoch: 9/200 Iteration: 900 Loss: 2.3284378051757812
# Epoch: 11/200 Iteration: 1000 Loss: 2.0957953929901123
# Epoch: 12/200 Iteration: 1100 Loss: 1.7222250699996948
# Epoch: 13/200 Iteration: 1200 Loss: 1.478082537651062
# Epoch: 14/200 Iteration: 1300 Loss: 1.7629753351211548
# Epoch: 15/200 Iteration: 1400 Loss: 1.6222481727600098
# Epoch: 16/200 Iteration: 1500 Loss: 1.296867847442627
# Epoch: 17/200 Iteration: 1600 Loss: 1.4441113471984863
# Epoch: 18/200 Iteration: 1700 Loss: 1.2267210483551025
# Epoch: 19/200 Iteration: 1800 Loss: 1.2128852605819702
# Epoch: 21/200 Iteration: 1900 Loss: 0.9956995844841003
# Epoch: 22/200 Iteration: 2000 Loss: 0.8037139177322388
# Epoch: 23/200 Iteration: 2100 Loss: 0.8778703212738037
# Epoch: 24/200 Iteration: 2200 Loss: 1.0423784255981445
# Epoch: 25/200 Iteration: 2300 Loss: 0.9278473854064941
# Epoch: 26/200 Iteration: 2400 Loss: 0.7622814774513245
# Epoch: 27/200 Iteration: 2500 Loss: 0.8372387886047363
# Epoch: 28/200 Iteration: 2600 Loss: 0.7502784729003906
# Epoch: 29/200 Iteration: 2700 Loss: 0.7683459520339966
# Epoch: 31/200 Iteration: 2800 Loss: 0.6462778449058533
# Epoch: 32/200 Iteration: 2900 Loss: 0.5055212378501892
# Epoch: 33/200 Iteration: 3000 Loss: 0.6752989292144775
# Epoch: 34/200 Iteration: 3100 Loss: 0.7304680347442627
# Epoch: 35/200 Iteration: 3200 Loss: 0.6671256422996521
# Epoch: 36/200 Iteration: 3300 Loss: 0.5818922519683838
# Epoch: 37/200 Iteration: 3400 Loss: 0.6606218814849854
# Epoch: 38/200 Iteration: 3500 Loss: 0.5202857851982117
# Epoch: 39/200 Iteration: 3600 Loss: 0.5629855394363403
# Epoch: 41/200 Iteration: 3700 Loss: 0.44179320335388184
# Epoch: 42/200 Iteration: 3800 Loss: 0.3792300522327423
# Epoch: 43/200 Iteration: 3900 Loss: 0.48332419991493225
# Epoch: 44/200 Iteration: 4000 Loss: 0.5465628504753113
# Epoch: 45/200 Iteration: 4100 Loss: 0.5342603921890259
# Epoch: 46/200 Iteration: 4200 Loss: 0.39347830414772034
# Epoch: 47/200 Iteration: 4300 Loss: 0.49513378739356995
# Epoch: 48/200 Iteration: 4400 Loss: 0.41935479640960693
# Epoch: 49/200 Iteration: 4500 Loss: 0.47578924894332886

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])
    print(' '.join(words))

def main(sentences):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
        sentences, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, ['君','が'], n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.216294288635254
# Epoch: 2/200 Iteration: 200 Loss: 5.484551906585693
# Epoch: 3/200 Iteration: 300 Loss: 4.5901594161987305
# Epoch: 4/200 Iteration: 400 Loss: 4.167818546295166
# Epoch: 5/200 Iteration: 500 Loss: 3.782728672027588
# Epoch: 6/200 Iteration: 600 Loss: 3.052025079727173
# Epoch: 7/200 Iteration: 700 Loss: 3.112175464630127
# Epoch: 8/200 Iteration: 800 Loss: 2.436324119567871
# Epoch: 9/200 Iteration: 900 Loss: 2.281820058822632
# Epoch: 11/200 Iteration: 1000 Loss: 2.042019844055176
# 君 が 好き
# Epoch: 12/200 Iteration: 1100 Loss: 1.748046875
# Epoch: 13/200 Iteration: 1200 Loss: 1.5879687070846558
# Epoch: 14/200 Iteration: 1300 Loss: 1.8384432792663574
# Epoch: 15/200 Iteration: 1400 Loss: 1.5751291513442993
# Epoch: 16/200 Iteration: 1500 Loss: 1.2501041889190674
# Epoch: 17/200 Iteration: 1600 Loss: 1.5430318117141724
# Epoch: 18/200 Iteration: 1700 Loss: 1.324999451637268
# Epoch: 19/200 Iteration: 1800 Loss: 1.1741139888763428
# Epoch: 21/200 Iteration: 1900 Loss: 0.9458746910095215
# Epoch: 22/200 Iteration: 2000 Loss: 0.8466799259185791
# 君 が 桟橋
# Epoch: 23/200 Iteration: 2100 Loss: 0.9399438500404358
# Epoch: 24/200 Iteration: 2200 Loss: 1.1666523218154907
# Epoch: 25/200 Iteration: 2300 Loss: 0.9708532094955444
# Epoch: 26/200 Iteration: 2400 Loss: 0.7822499871253967
# Epoch: 27/200 Iteration: 2500 Loss: 0.9051418304443359
# Epoch: 28/200 Iteration: 2600 Loss: 0.7659725546836853
# Epoch: 29/200 Iteration: 2700 Loss: 0.8726958632469177
# Epoch: 31/200 Iteration: 2800 Loss: 0.5815215110778809
# Epoch: 32/200 Iteration: 2900 Loss: 0.5199316143989563
# Epoch: 33/200 Iteration: 3000 Loss: 0.6854392886161804
# 君 が 溢れ
# Epoch: 34/200 Iteration: 3100 Loss: 0.8959519863128662
# Epoch: 35/200 Iteration: 3200 Loss: 0.6646593809127808
# Epoch: 36/200 Iteration: 3300 Loss: 0.6044645309448242
# Epoch: 37/200 Iteration: 3400 Loss: 0.6501864790916443
# Epoch: 38/200 Iteration: 3500 Loss: 0.5843651294708252
# Epoch: 39/200 Iteration: 3600 Loss: 0.6294616460800171
# Epoch: 41/200 Iteration: 3700 Loss: 0.4042506814002991
# Epoch: 42/200 Iteration: 3800 Loss: 0.3752053678035736
# Epoch: 43/200 Iteration: 3900 Loss: 0.5716748237609863
# Epoch: 44/200 Iteration: 4000 Loss: 0.7205663919448853
# 君 が 思い通り
# Epoch: 45/200 Iteration: 4100 Loss: 0.5220718383789062
# Epoch: 46/200 Iteration: 4200 Loss: 0.4479258358478546
# Epoch: 47/200 Iteration: 4300 Loss: 0.5287290811538696
# Epoch: 48/200 Iteration: 4400 Loss: 0.4149531424045563
# Epoch: 49/200 Iteration: 4500 Loss: 0.5386975407600403

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])
    print(' '.join(words))

def main(sentences):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
        sentences, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, ['永遠','に','中学生'], n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.242039680480957
# Epoch: 2/200 Iteration: 200 Loss: 5.683346271514893
# Epoch: 3/200 Iteration: 300 Loss: 4.478631496429443
# Epoch: 4/200 Iteration: 400 Loss: 4.258714199066162
# Epoch: 5/200 Iteration: 500 Loss: 3.679887533187866
# Epoch: 6/200 Iteration: 600 Loss: 3.0213265419006348
# Epoch: 7/200 Iteration: 700 Loss: 3.0591557025909424
# Epoch: 8/200 Iteration: 800 Loss: 2.425447940826416
# Epoch: 9/200 Iteration: 900 Loss: 2.3756825923919678
# Epoch: 11/200 Iteration: 1000 Loss: 2.1044604778289795
# 永遠 に 中学生 文句
# Epoch: 12/200 Iteration: 1100 Loss: 1.7734441757202148
# Epoch: 13/200 Iteration: 1200 Loss: 1.5780584812164307
# Epoch: 14/200 Iteration: 1300 Loss: 1.8471558094024658
# Epoch: 15/200 Iteration: 1400 Loss: 1.7631975412368774
# Epoch: 16/200 Iteration: 1500 Loss: 1.3566402196884155
# Epoch: 17/200 Iteration: 1600 Loss: 1.585843801498413
# Epoch: 18/200 Iteration: 1700 Loss: 1.1868138313293457
# Epoch: 19/200 Iteration: 1800 Loss: 1.256837248802185
# Epoch: 21/200 Iteration: 1900 Loss: 1.0211584568023682
# Epoch: 22/200 Iteration: 2000 Loss: 0.8251839876174927
# 永遠 に 中学生 いつ
# Epoch: 23/200 Iteration: 2100 Loss: 0.9058876633644104
# Epoch: 24/200 Iteration: 2200 Loss: 1.167495608329773
# Epoch: 25/200 Iteration: 2300 Loss: 1.0869050025939941
# Epoch: 26/200 Iteration: 2400 Loss: 0.8349856734275818
# Epoch: 27/200 Iteration: 2500 Loss: 0.9361463785171509
# Epoch: 28/200 Iteration: 2600 Loss: 0.7148115038871765
# Epoch: 29/200 Iteration: 2700 Loss: 0.8499231934547424
# Epoch: 31/200 Iteration: 2800 Loss: 0.6815110445022583
# Epoch: 32/200 Iteration: 2900 Loss: 0.5465255379676819
# Epoch: 33/200 Iteration: 3000 Loss: 0.6779195666313171
# 永遠 に 中学生 に
# Epoch: 34/200 Iteration: 3100 Loss: 0.8280347585678101
# Epoch: 35/200 Iteration: 3200 Loss: 0.7623796463012695
# Epoch: 36/200 Iteration: 3300 Loss: 0.5769152641296387
# Epoch: 37/200 Iteration: 3400 Loss: 0.7120551466941833
# Epoch: 38/200 Iteration: 3500 Loss: 0.5473406910896301
# Epoch: 39/200 Iteration: 3600 Loss: 0.6206884980201721
# Epoch: 41/200 Iteration: 3700 Loss: 0.4844675362110138
# Epoch: 42/200 Iteration: 3800 Loss: 0.387158066034317
# Epoch: 43/200 Iteration: 3900 Loss: 0.5142083764076233
# Epoch: 44/200 Iteration: 4000 Loss: 0.6667044758796692
# 永遠 に 中学生 だろ
# Epoch: 45/200 Iteration: 4100 Loss: 0.5784693956375122
# Epoch: 46/200 Iteration: 4200 Loss: 0.48067089915275574
# Epoch: 47/200 Iteration: 4300 Loss: 0.6423473954200745
# Epoch: 48/200 Iteration: 4400 Loss: 0.4400864839553833
# Epoch: 49/200 Iteration: 4500 Loss: 0.5635242462158203

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.dense(output)

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

def predict(device, net, words, n_vocab, vocab_to_int, int_to_vocab, top_k=5):
    net.eval()

    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))
    
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])
    print(' '.join(words))

def main(sentences):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data_from_text(
        sentences, flags.batch_size, flags.seq_size)

    net = RNNModule(n_vocab, flags.seq_size,
                    flags.embedding_size, flags.lstm_size)
    net = net.to(device)

    criterion, optimizer = get_loss_and_train_op(net, 0.01)

    iteration = 0

    for e in range(50):
        batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
        state_h, state_c = net.zero_state(flags.batch_size)
    
        # Transfer data to GPU
        state_h = state_h.to(device)
        state_c = state_c.to(device)
        for x, y in batches:
            iteration += 1
            
            # Tell it we are in training mode
            net.train()

            # Reset all gradients
            optimizer.zero_grad()

            # Transfer data to GPU
            x = torch.tensor(x).to(device)
            y = torch.tensor(y).to(device)

            logits, (state_h, state_c) = net(x, (state_h, state_c))
            loss = criterion(logits.transpose(1, 2), y)

            state_h = state_h.detach()
            state_c = state_c.detach()

            loss_value = loss.item()

            # Perform back-propagation
            loss.backward()

            # Update the network's parameters
            _ = torch.nn.utils.clip_grad_norm_(net.parameters(), flags.gradients_norm)

            optimizer.step()

            if iteration % 100 == 0:
                print('Epoch: {}/{}'.format(e, 200),
                        'Iteration: {}'.format(iteration),
                        'Loss: {}'.format(loss_value))

            if iteration % 1000 == 0:
                predict(device, net, ['ティッシュ'], n_vocab,
                        vocab_to_int, int_to_vocab, top_k=5)
                torch.save(net.state_dict(),
                            'checkpoint_pt/model-{}.pth'.format(iteration))

# %%
main(' '.join(sentences))
# Out:
# Vocabulary size 6761
# Epoch: 1/200 Iteration: 100 Loss: 6.26841926574707
# Epoch: 2/200 Iteration: 200 Loss: 5.597729682922363
# Epoch: 3/200 Iteration: 300 Loss: 4.577959060668945
# Epoch: 4/200 Iteration: 400 Loss: 4.176708698272705
# Epoch: 5/200 Iteration: 500 Loss: 3.9781599044799805
# Epoch: 6/200 Iteration: 600 Loss: 3.239243268966675
# Epoch: 7/200 Iteration: 700 Loss: 3.036607503890991
# Epoch: 8/200 Iteration: 800 Loss: 2.4898624420166016
# Epoch: 9/200 Iteration: 900 Loss: 2.310070753097534
# Epoch: 11/200 Iteration: 1000 Loss: 2.033055305480957
# ティッシュ !
# Epoch: 12/200 Iteration: 1100 Loss: 1.6905882358551025
# Epoch: 13/200 Iteration: 1200 Loss: 1.6019442081451416
# Epoch: 14/200 Iteration: 1300 Loss: 1.7570836544036865
# Epoch: 15/200 Iteration: 1400 Loss: 1.7435879707336426
# Epoch: 16/200 Iteration: 1500 Loss: 1.3418911695480347
# Epoch: 17/200 Iteration: 1600 Loss: 1.5010851621627808
# Epoch: 18/200 Iteration: 1700 Loss: 1.2316581010818481
# Epoch: 19/200 Iteration: 1800 Loss: 1.210929036140442
# Epoch: 21/200 Iteration: 1900 Loss: 0.9937337040901184
# Epoch: 22/200 Iteration: 2000 Loss: 0.8386560082435608
# ティッシュ と
# Epoch: 23/200 Iteration: 2100 Loss: 0.973223865032196
# Epoch: 24/200 Iteration: 2200 Loss: 1.092869758605957
# Epoch: 25/200 Iteration: 2300 Loss: 1.0140024423599243
# Epoch: 26/200 Iteration: 2400 Loss: 0.8354580402374268
# Epoch: 27/200 Iteration: 2500 Loss: 1.0223829746246338
# Epoch: 28/200 Iteration: 2600 Loss: 0.8137673735618591
# Epoch: 29/200 Iteration: 2700 Loss: 0.809469997882843
# Epoch: 31/200 Iteration: 2800 Loss: 0.5701372623443604
# Epoch: 32/200 Iteration: 2900 Loss: 0.5013777017593384
# Epoch: 33/200 Iteration: 3000 Loss: 0.6220147609710693
# ティッシュ 」
# Epoch: 34/200 Iteration: 3100 Loss: 0.7934738397598267
# Epoch: 35/200 Iteration: 3200 Loss: 0.7070924639701843
# Epoch: 36/200 Iteration: 3300 Loss: 0.5803055763244629
# Epoch: 37/200 Iteration: 3400 Loss: 0.7517726421356201
# Epoch: 38/200 Iteration: 3500 Loss: 0.5419094562530518
# Epoch: 39/200 Iteration: 3600 Loss: 0.6392077207565308
# Epoch: 41/200 Iteration: 3700 Loss: 0.4188362658023834
# Epoch: 42/200 Iteration: 3800 Loss: 0.3466927409172058
# Epoch: 43/200 Iteration: 3900 Loss: 0.5416529178619385
# Epoch: 44/200 Iteration: 4000 Loss: 0.6156772375106812
# ティッシュ な
# Epoch: 45/200 Iteration: 4100 Loss: 0.573413074016571
# Epoch: 46/200 Iteration: 4200 Loss: 0.44425272941589355
# Epoch: 47/200 Iteration: 4300 Loss: 0.6175994277000427
# Epoch: 48/200 Iteration: 4400 Loss: 0.4755016565322876
# Epoch: 49/200 Iteration: 4500 Loss: 0.556341826915741
